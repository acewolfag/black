# %% [markdown]
# <a href="https://colab.research.google.com/github/acewolfag/black/blob/main/FaceNet_PyTourch.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# IMPORTANT: SOME KAGGLE DATA SOURCES ARE PRIVATE
# RUN THIS CELL IN ORDER TO IMPORT YOUR KAGGLE DATA SOURCES.
import kagglehub
kagglehub.login()
# Out:
# VBox(children=(HTML(value='<center> <img\nsrc=https://www.kaggle.com/static/images/site-logo.png\nalt=\'Kaggle…
# Kaggle credentials set.
# Kaggle credentials successfully validated.

# %%
# IMPORTANT: RUN THIS CELL IN ORDER TO IMPORT YOUR KAGGLE DATA SOURCES,
# THEN FEEL FREE TO DELETE THIS CELL.
# NOTE: THIS NOTEBOOK ENVIRONMENT DIFFERS FROM KAGGLE'S PYTHON
# ENVIRONMENT SO THERE MAY BE MISSING LIBRARIES USED BY YOUR
# NOTEBOOK.

dansbecker_5_celebrity_faces_dataset_path = kagglehub.dataset_download('dansbecker/5-celebrity-faces-dataset')
timesler_facenet_pytorch_vggface2_path = kagglehub.dataset_download('timesler/facenet-pytorch-vggface2')
acewolfag_facenet_dataset_path = kagglehub.dataset_download('acewolfag/facenet-dataset')

print('Data source import complete.')
# Out:
# Downloading from https://www.kaggle.com/api/v1/datasets/download/acewolfag/facenet-dataset?dataset_version_number=1...
# 100%|██████████| 713M/713M [00:10<00:00, 74.2MB/s]
# Extracting files...
# Data source import complete.

# %% [markdown]
# # Face Recognition using Facenet and SVM with PCA Visualization
#
# The provided code implements a face recognition system using the [facenet-pytorch](https://www.kaggle.com/datasets/timesler/facenet-pytorch-vggface2) library and training using SVM Model. Here's a summary of the code:
#
# 1. Installation: The code installs the facenet-pytorch library from a local file using pip.
# 2. Model Checkpoints: The code copies the model checkpoints to the torch cache directory for automatic loading during runtime.
# 3. Importing Required Libraries: Necessary libraries and modules are imported for various functionalities, including image processing, machine learning, face detection, and feature extraction.
# 4. Helper Functions: Two helper functions are defined. The whitens function normalizes an input image tensor, and the extract_features function detects faces in an image and extracts their feature embeddings.
# 5. Device Configuration: The code sets the device to either GPU or CPU based on availability.
# 6. Model Initialization: The MTCNN and Inception ResNet V1 models are initialized with pre-trained weights. The models are moved to the selected device.
# 7. Dataset Preparation: The code defines the path to the dataset folder and creates ImageFolder datasets for the training and validation sets.
# 8. Embedding Extraction: The dataset_to_embeddings function is called to extract face embeddings from the training and validation sets.
# 9. Model Training: The train function is called to train the face recognition model using the extracted embeddings.
# 10. Model Saving: The trained model is serialized and saved as a pickle file.
# 11. Model Evaluation: The code generates a classification report and calculates the accuracy of the trained model using the embeddings from the training set.
# 12. Visualization: The code uses PCA to reduce the dimensionality of the embeddings and plots a 2D scatter plot of the embeddings with different colors representing different labels.
# 13. Image Testing: Random images from the validation set are selected and their predicted labels are compared with the true labels. The images, along with the predicted and actual labels, are displayed.
# 14. Single Image Testing: A single image is tested for face recognition, and the predicted label is displayed along with the image.

# %% [markdown]
# ## Importing Required Libraries
#
# The necessary libraries and modules are imported, including:

# %%
import os
import shutil
from sklearn.model_selection import train_test_split
path_folder = "/root/.cache/kagglehub/datasets/acewolfag/facenet-dataset/versions/1/Original Images"
# Đường dẫn gốc đến thư mục chứa dữ liệu
source_folder = "/root/.cache/kagglehub/datasets/acewolfag/facenet-dataset/versions/1/Original Images"
train_folder = "/content/train"
val_folder = "/content/val"

# Tạo thư mục train và val nếu chưa có
os.makedirs(train_folder, exist_ok=True)
os.makedirs(val_folder, exist_ok=True)

# Lặp qua tất cả các folder (tương ứng với từng class)
for person in os.listdir(source_folder):
    person_path = os.path.join(source_folder, person)

    # Kiểm tra nếu đó là một folder
    if os.path.isdir(person_path):
        # Lấy danh sách các file trong folder person
        images = os.listdir(person_path)

        # Chia dữ liệu theo tỷ lệ train và val
        train_images, val_images = train_test_split(images, test_size=0.2, random_state=42)

        # Tạo thư mục cho class trong train và val
        train_class_folder = os.path.join(train_folder, person)
        val_class_folder = os.path.join(val_folder, person)
        os.makedirs(train_class_folder, exist_ok=True)
        os.makedirs(val_class_folder, exist_ok=True)

        # Di chuyển file vào thư mục tương ứng
        for image in train_images:
            shutil.copy(os.path.join(person_path, image), os.path.join(train_class_folder, image))

        for image in val_images:
            shutil.copy(os.path.join(person_path, image), os.path.join(val_class_folder, image))

        print(f"Đã hoàn thành phân chia cho class {person}")

print("Đã hoàn tất phân chia dữ liệu!")
# Out:
# Đã hoàn thành phân chia cho class Claire Holt
# Đã hoàn thành phân chia cho class Zac Efron
# Đã hoàn thành phân chia cho class Marmik
# Đã hoàn thành phân chia cho class Akshay Kumar
# Đã hoàn thành phân chia cho class Virat Kohli
# Đã hoàn thành phân chia cho class Alexandra Daddario
# Đã hoàn thành phân chia cho class Hrithik Roshan
# Đã hoàn thành phân chia cho class Andy Samberg
# Đã hoàn thành phân chia cho class Billie Eilish
# Đã hoàn thành phân chia cho class Hugh Jackman
# Đã hoàn thành phân chia cho class Roger Federer
# Đã hoàn thành phân chia cho class Elizabeth Olsen
# Đã hoàn thành phân chia cho class Camila Cabello
# Đã hoàn thành phân chia cho class Brad Pitt
# Đã hoàn thành phân chia cho class Margot Robbie
# Đã hoàn thành phân chia cho class Jessica Alba
# Đã hoàn thành phân chia cho class Charlize Theron
# Đã hoàn thành phân chia cho class Dwayne Johnson
# Đã hoàn thành phân chia cho class Amitabh Bachchan
# Đã hoàn thành phân chia cho class Anushka Sharma
# Đã hoàn thành phân chia cho class Kashyap
# Đã hoàn thành phân chia cho class Lisa Kudrow
# Đã hoàn thành phân chia cho class Alia Bhatt
# Đã hoàn thành phân chia cho class Ellen Degeneres
# Đã hoàn thành phân chia cho class Tom Cruise
# Đã hoàn thành phân chia cho class Robert Downey Jr
# Đã hoàn thành phân chia cho class Courtney Cox
# Đã hoàn thành phân chia cho class Vijay Deverakonda
# Đã hoàn thành phân chia cho class Priyanka Chopra
# Đã hoàn thành phân chia cho class Henry Cavill
# Đã hoàn thành phân chia cho class Natalie Portman
# Đã hoàn tất phân chia dữ liệu!

# %%
# !pip install facenet-pytorch
# Out:
# Requirement already satisfied: facenet-pytorch in /usr/local/lib/python3.10/dist-packages (2.6.0)
# Requirement already satisfied: numpy<2.0.0,>=1.24.0 in /usr/local/lib/python3.10/dist-packages (from facenet-pytorch) (1.26.4)
# Requirement already satisfied: Pillow<10.3.0,>=10.2.0 in /usr/local/lib/python3.10/dist-packages (from facenet-pytorch) (10.2.0)
# Requirement already satisfied: requests<3.0.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from facenet-pytorch) (2.32.3)
# Requirement already satisfied: torch<2.3.0,>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from facenet-pytorch) (2.2.2)
# Requirement already satisfied: torchvision<0.18.0,>=0.17.0 in /usr/local/lib/python3.10/dist-packages (from facenet-pytorch) (0.17.2)
# Requirement already satisfied: tqdm<5.0.0,>=4.0.0 in /usr/local/lib/python3.10/dist-packages (from facenet-pytorch) (4.66.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.0.0->facenet-pytorch) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.0.0->facenet-pytorch) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.0.0->facenet-pytorch) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.0.0->facenet-pytorch) (2024.8.30)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch<2.3.0,>=2.2.0->facenet-pytorch) (3.16.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch<2.3.0,>=2.2.0->facenet-pytorch) (4.12.2)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch<2.3.0,>=2.2.0->facenet-pytorch) (1.13.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch<2.3.0,>=2.2.0->facenet-pytorch) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch<2.3.0,>=2.2.0->facenet-pytorch) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch<2.3.0,>=2.2.0->facenet-pytorch) (2024.6.1)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch<2.3.0,>=2.2.0->facenet-pytorch) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch<2.3.0,>=2.2.0->facenet-pytorch) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch<2.3.0,>=2.2.0->facenet-pytorch) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in /usr/local/lib/python3.10/dist-packages (from torch<2.3.0,>=2.2.0->facenet-pytorch) (8.9.2.26)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /usr/local/lib/python3.10/dist-packages (from torch<2.3.0,>=2.2.0->facenet-pytorch) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /usr/local/lib/python3.10/dist-packages (from torch<2.3.0,>=2.2.0->facenet-pytorch) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /usr/local/lib/python3.10/dist-packages (from torch<2.3.0,>=2.2.0->facenet-pytorch) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /usr/local/lib/python3.10/dist-packages (from torch<2.3.0,>=2.2.0->facenet-pytorch) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /usr/local/lib/python3.10/dist-packages (from torch<2.3.0,>=2.2.0->facenet-pytorch) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.19.3 in /usr/local/lib/python3.10/dist-packages (from torch<2.3.0,>=2.2.0->facenet-pytorch) (2.19.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch<2.3.0,>=2.2.0->facenet-pytorch) (12.1.105)
# Requirement already satisfied: triton==2.2.0 in /usr/local/lib/python3.10/dist-packages (from torch<2.3.0,>=2.2.0->facenet-pytorch) (2.2.0)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /usr/local/lib/python3.10/dist-packages (from nvidia-cusolver-cu12==11.4.5.107->torch<2.3.0,>=2.2.0->facenet-pytorch) (12.6.77)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch<2.3.0,>=2.2.0->facenet-pytorch) (3.0.2)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy->torch<2.3.0,>=2.2.0->facenet-pytorch) (1.3.0)

# %%
import os
import argparse
import joblib
import numpy as np
from PIL import Image
from torchvision import transforms, datasets
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import GridSearchCV
from sklearn import metrics
from sklearn.metrics import accuracy_score
import joblib
import random
import matplotlib.pyplot as plt
from facenet_pytorch import MTCNN, InceptionResnetV1, extract_face
import torch
from sklearn.decomposition import PCA
from sklearn import svm

# %% [markdown]
# ## Utility Functions
#
# The following utility functions are defined:
#
# * **whitens(img):** Performs image whitening by subtracting the mean and dividing by the standard deviation of the image.
# * **extract_features(mtcnn, facenet, img):** Extracts facial features from an image using the MTCNN face detection and the InceptionResnetV1 model. Returns the bounding boxes and embeddings of detected faces.
# * **dataset_to_embeddings(dataset, mtcnn, facenet):** Converts a dataset of images into a list of embeddings and labels using the MTCNN and InceptionResnetV1 models.
# * **train(embeddings, labels):** Train the embeddings and labels using SVM Model with True probability

# %%
def whitens(img):
        mean = img.mean()
        std = img.std()
        std_adj = std.clamp(min=1.0 / (float(img.numel()) ** 0.5))
        y = (img - mean) / std_adj
        return y

def extract_features(mtcnn, facenet, img):
        img = img.to(device)
        img = transforms.ToPILImage()(img.squeeze_(0))
        bbs, _ = mtcnn.detect(img)
        if bbs is None:
            # if no face is detected
            return None, None

        faces = torch.stack([extract_face(img, bb) for bb in bbs])
        embeddings = facenet(whitens(faces)).detach().numpy()

        return bbs, embeddings

def dataset_to_embeddings(dataset, mtcnn, facenet):
    transform = transforms.Compose([
        transforms.Resize(1024),
        transforms.ToTensor()
    ])

    embeddings = []
    labels = []
    for img_path, label in dataset.samples:
        print(img_path)

        _, embedding = extract_features(mtcnn, facenet, transform(Image.open(img_path).convert('RGB')).unsqueeze_(0))
        if embedding is None:
            print("Could not find face on {}".format(img_path))
            continue
        if embedding.shape[0] > 1:
            print("Multiple faces detected for {}, taking one with highest probability".format(img_path))
            embedding = embedding[0, :]
        embeddings.append(embedding.flatten())
        labels.append(label)

    return np.stack(embeddings), labels

def train(embeddings, labels):
    clf = svm.SVC(probability=True)
    clf.fit(embeddings, labels)
    return clf

# %% [markdown]
# ## Model Initialization
# The code initializes the MTCNN and InceptionResnetV1 models for face detection and feature extraction, respectively:

# %%
device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')
device='cpu'

mtcnn = MTCNN(keep_all=True, thresholds=[0.6, 0.7, 0.9], device=device)
facenet = InceptionResnetV1(pretrained='vggface2').eval()

facenet = facenet.to(device)

# %% [markdown]
# ## Dataset Preparation
# The code defines the path to the dataset folder and creates ImageFolder datasets for training and validation:

# %%
data_path = path_folder
train_path = "/content/train"
val_path = "/content/val"

dataset_train = datasets.ImageFolder(root=train_path)
dataset_val = datasets.ImageFolder(root=val_path)

# %% [markdown]
# ## Generating Embeddings
# The code generates embeddings and labels for the training and validation datasets using the dataset_to_embeddings function:

# %%
X_train, y_train = dataset_to_embeddings(dataset_train, mtcnn, facenet)
X_test, y_test = dataset_to_embeddings(dataset_val, mtcnn, facenet)

X_train_class_idx = dataset_train.class_to_idx
X_test_class_idx = dataset_val.class_to_idx

embeddings, labels, class_to_idx = X_train, y_train, X_train_class_idx
# Out:
# /content/train/Akshay Kumar/Akshay Kumar_0.jpg
# /content/train/Akshay Kumar/Akshay Kumar_1.jpg
# /content/train/Akshay Kumar/Akshay Kumar_10.jpg
# /content/train/Akshay Kumar/Akshay Kumar_11.jpg
# /content/train/Akshay Kumar/Akshay Kumar_12.jpg
# /content/train/Akshay Kumar/Akshay Kumar_13.jpg
# /content/train/Akshay Kumar/Akshay Kumar_14.jpg
# /content/train/Akshay Kumar/Akshay Kumar_15.jpg
# /content/train/Akshay Kumar/Akshay Kumar_17.jpg
# /content/train/Akshay Kumar/Akshay Kumar_18.jpg
# /content/train/Akshay Kumar/Akshay Kumar_19.jpg
# /content/train/Akshay Kumar/Akshay Kumar_20.jpg
# /content/train/Akshay Kumar/Akshay Kumar_21.jpg
# /content/train/Akshay Kumar/Akshay Kumar_22.jpg
# /content/train/Akshay Kumar/Akshay Kumar_23.jpg
# /content/train/Akshay Kumar/Akshay Kumar_24.jpg
# Multiple faces detected for /content/train/Akshay Kumar/Akshay Kumar_24.jpg, taking one with highest probability
# /content/train/Akshay Kumar/Akshay Kumar_25.jpg
# /content/train/Akshay Kumar/Akshay Kumar_26.jpg
# /content/train/Akshay Kumar/Akshay Kumar_28.jpg
# /content/train/Akshay Kumar/Akshay Kumar_30.jpg
# /content/train/Akshay Kumar/Akshay Kumar_32.jpg
# /content/train/Akshay Kumar/Akshay Kumar_33.jpg
# /content/train/Akshay Kumar/Akshay Kumar_34.jpg
# /content/train/Akshay Kumar/Akshay Kumar_35.jpg
# /content/train/Akshay Kumar/Akshay Kumar_36.jpg
# /content/train/Akshay Kumar/Akshay Kumar_38.jpg
# /content/train/Akshay Kumar/Akshay Kumar_4.jpg
# Multiple faces detected for /content/train/Akshay Kumar/Akshay Kumar_4.jpg, taking one with highest probability
# /content/train/Akshay Kumar/Akshay Kumar_40.jpg
# /content/train/Akshay Kumar/Akshay Kumar_41.jpg
# /content/train/Akshay Kumar/Akshay Kumar_43.jpg
# /content/train/Akshay Kumar/Akshay Kumar_44.jpg
# /content/train/Akshay Kumar/Akshay Kumar_46.jpg
# /content/train/Akshay Kumar/Akshay Kumar_47.jpg
# /content/train/Akshay Kumar/Akshay Kumar_48.jpg
# /content/train/Akshay Kumar/Akshay Kumar_49.jpg
# /content/train/Akshay Kumar/Akshay Kumar_5.jpg
# Multiple faces detected for /content/train/Akshay Kumar/Akshay Kumar_5.jpg, taking one with highest probability
# /content/train/Akshay Kumar/Akshay Kumar_6.jpg
# /content/train/Akshay Kumar/Akshay Kumar_7.jpg
# /content/train/Akshay Kumar/Akshay Kumar_8.jpg
# /content/train/Akshay Kumar/Akshay Kumar_9.jpg
# /content/train/Alexandra Daddario/Alexandra Daddario_0.jpg
# /content/train/Alexandra Daddario/Alexandra Daddario_1.jpg
# /content/train/Alexandra Daddario/Alexandra Daddario_10.jpg
# /content/train/Alexandra Daddario/Alexandra Daddario_11.jpg
# /content/train/Alexandra Daddario/Alexandra Daddario_12.jpg
# /content/train/Alexandra Daddario/Alexandra Daddario_13.jpg
# /content/train/Alexandra Daddario/Alexandra Daddario_14.jpg
# /content/train/Alexandra Daddario/Alexandra Daddario_17.jpg
# /content/train/Alexandra Daddario/Alexandra Daddario_18.jpg
# /content/train/Alexandra Daddario/Alexandra Daddario_20.jpg
# /content/train/Alexandra Daddario/Alexandra Daddario_21.jpg
# /content/train/Alexandra Daddario/Alexandra Daddario_22.jpg
# /content/train/Alexandra Daddario/Alexandra Daddario_24.jpg
# /content/train/Alexandra Daddario/Alexandra Daddario_25.jpg
# /content/train/Alexandra Daddario/Alexandra Daddario_27.jpg
# /content/train/Alexandra Daddario/Alexandra Daddario_28.jpg
# /content/train/Alexandra Daddario/Alexandra Daddario_29.jpg
# Multiple faces detected for /content/train/Alexandra Daddario/Alexandra Daddario_29.jpg, taking one with highest probability
# /content/train/Alexandra Daddario/Alexandra Daddario_3.jpg
# /content/train/Alexandra Daddario/Alexandra Daddario_30.jpg
# /content/train/Alexandra Daddario/Alexandra Daddario_31.jpg
# /content/train/Alexandra Daddario/Alexandra Daddario_32.jpg
# /content/train/Alexandra Daddario/Alexandra Daddario_33.jpg
# /content/train/Alexandra Daddario/Alexandra Daddario_35.jpg
# /content/train/Alexandra Daddario/Alexandra Daddario_36.jpg
# /content/train/Alexandra Daddario/Alexandra Daddario_37.jpg
# /content/train/Alexandra Daddario/Alexandra Daddario_38.jpg
# /content/train/Alexandra Daddario/Alexandra Daddario_39.jpg
# /content/train/Alexandra Daddario/Alexandra Daddario_4.jpg
# /content/train/Alexandra Daddario/Alexandra Daddario_40.jpg
# /content/train/Alexandra Daddario/Alexandra Daddario_41.jpg
# /content/train/Alexandra Daddario/Alexandra Daddario_42.jpg
# /content/train/Alexandra Daddario/Alexandra Daddario_43.jpg
# /content/train/Alexandra Daddario/Alexandra Daddario_44.jpg
# /content/train/Alexandra Daddario/Alexandra Daddario_45.jpg
# /content/train/Alexandra Daddario/Alexandra Daddario_46.jpg
# /content/train/Alexandra Daddario/Alexandra Daddario_47.jpg
# /content/train/Alexandra Daddario/Alexandra Daddario_48.jpg
# /content/train/Alexandra Daddario/Alexandra Daddario_49.jpg
# /content/train/Alexandra Daddario/Alexandra Daddario_5.jpg
# /content/train/Alexandra Daddario/Alexandra Daddario_53.jpg
# /content/train/Alexandra Daddario/Alexandra Daddario_54.jpg
# /content/train/Alexandra Daddario/Alexandra Daddario_56.jpg
# /content/train/Alexandra Daddario/Alexandra Daddario_57.jpg
# /content/train/Alexandra Daddario/Alexandra Daddario_58.jpg
# /content/train/Alexandra Daddario/Alexandra Daddario_6.jpg
# /content/train/Alexandra Daddario/Alexandra Daddario_60.jpg
# Multiple faces detected for /content/train/Alexandra Daddario/Alexandra Daddario_60.jpg, taking one with highest probability
# /content/train/Alexandra Daddario/Alexandra Daddario_61.jpg
# /content/train/Alexandra Daddario/Alexandra Daddario_62.jpg
# /content/train/Alexandra Daddario/Alexandra Daddario_63.jpg
# /content/train/Alexandra Daddario/Alexandra Daddario_65.jpg
# /content/train/Alexandra Daddario/Alexandra Daddario_66.jpg
# /content/train/Alexandra Daddario/Alexandra Daddario_67.jpg
# /content/train/Alexandra Daddario/Alexandra Daddario_68.jpg
# /content/train/Alexandra Daddario/Alexandra Daddario_69.jpg
# /content/train/Alexandra Daddario/Alexandra Daddario_7.jpg
# /content/train/Alexandra Daddario/Alexandra Daddario_70.jpg
# /content/train/Alexandra Daddario/Alexandra Daddario_71.jpg
# /content/train/Alexandra Daddario/Alexandra Daddario_72.jpg
# /content/train/Alexandra Daddario/Alexandra Daddario_73.jpg
# /content/train/Alexandra Daddario/Alexandra Daddario_74.jpg
# /content/train/Alexandra Daddario/Alexandra Daddario_75.jpg
# /content/train/Alexandra Daddario/Alexandra Daddario_76.jpg
# /content/train/Alexandra Daddario/Alexandra Daddario_77.jpg
# /content/train/Alexandra Daddario/Alexandra Daddario_79.jpg
# /content/train/Alexandra Daddario/Alexandra Daddario_8.jpg
# /content/train/Alexandra Daddario/Alexandra Daddario_81.jpg
# Multiple faces detected for /content/train/Alexandra Daddario/Alexandra Daddario_81.jpg, taking one with highest probability
# /content/train/Alexandra Daddario/Alexandra Daddario_82.jpg
# /content/train/Alexandra Daddario/Alexandra Daddario_83.jpg
# /content/train/Alexandra Daddario/Alexandra Daddario_85.jpg
# /content/train/Alexandra Daddario/Alexandra Daddario_88.jpg
# Multiple faces detected for /content/train/Alexandra Daddario/Alexandra Daddario_88.jpg, taking one with highest probability
# /content/train/Alexandra Daddario/Alexandra Daddario_9.jpg
# /content/train/Alexandra Daddario/Alexandra Daddario_90.jpg
# /content/train/Alexandra Daddario/Alexandra Daddario_91.jpg
# /content/train/Alia Bhatt/Alia Bhatt_0.jpg
# /content/train/Alia Bhatt/Alia Bhatt_1.jpg
# /content/train/Alia Bhatt/Alia Bhatt_11.jpg
# /content/train/Alia Bhatt/Alia Bhatt_12.jpg
# /content/train/Alia Bhatt/Alia Bhatt_15.jpg
# /content/train/Alia Bhatt/Alia Bhatt_16.jpg
# /content/train/Alia Bhatt/Alia Bhatt_17.jpg
# /content/train/Alia Bhatt/Alia Bhatt_18.jpg
# /content/train/Alia Bhatt/Alia Bhatt_2.jpg
# /content/train/Alia Bhatt/Alia Bhatt_20.jpg
# /content/train/Alia Bhatt/Alia Bhatt_21.jpg
# /content/train/Alia Bhatt/Alia Bhatt_22.jpg
# /content/train/Alia Bhatt/Alia Bhatt_23.jpg
# /content/train/Alia Bhatt/Alia Bhatt_24.jpg
# /content/train/Alia Bhatt/Alia Bhatt_25.jpg
# /content/train/Alia Bhatt/Alia Bhatt_26.jpg
# /content/train/Alia Bhatt/Alia Bhatt_27.jpg
# /content/train/Alia Bhatt/Alia Bhatt_28.jpg
# /content/train/Alia Bhatt/Alia Bhatt_29.jpg
# Multiple faces detected for /content/train/Alia Bhatt/Alia Bhatt_29.jpg, taking one with highest probability
# /content/train/Alia Bhatt/Alia Bhatt_3.jpg
# /content/train/Alia Bhatt/Alia Bhatt_33.jpg
# /content/train/Alia Bhatt/Alia Bhatt_34.jpg
# /content/train/Alia Bhatt/Alia Bhatt_35.jpg
# /content/train/Alia Bhatt/Alia Bhatt_37.jpg
# /content/train/Alia Bhatt/Alia Bhatt_38.jpg
# /content/train/Alia Bhatt/Alia Bhatt_4.jpg
# /content/train/Alia Bhatt/Alia Bhatt_40.jpg
# /content/train/Alia Bhatt/Alia Bhatt_41.jpg
# Multiple faces detected for /content/train/Alia Bhatt/Alia Bhatt_41.jpg, taking one with highest probability
# /content/train/Alia Bhatt/Alia Bhatt_42.jpg
# /content/train/Alia Bhatt/Alia Bhatt_43.jpg
# /content/train/Alia Bhatt/Alia Bhatt_44.jpg
# /content/train/Alia Bhatt/Alia Bhatt_45.jpg
# /content/train/Alia Bhatt/Alia Bhatt_46.jpg
# /content/train/Alia Bhatt/Alia Bhatt_47.jpg
# /content/train/Alia Bhatt/Alia Bhatt_49.jpg
# /content/train/Alia Bhatt/Alia Bhatt_5.jpg
# /content/train/Alia Bhatt/Alia Bhatt_50.jpg
# /content/train/Alia Bhatt/Alia Bhatt_51.jpg
# /content/train/Alia Bhatt/Alia Bhatt_52.jpg
# /content/train/Alia Bhatt/Alia Bhatt_53.jpg
# /content/train/Alia Bhatt/Alia Bhatt_54.jpg
# /content/train/Alia Bhatt/Alia Bhatt_55.jpg
# /content/train/Alia Bhatt/Alia Bhatt_56.jpg
# /content/train/Alia Bhatt/Alia Bhatt_58.jpg
# /content/train/Alia Bhatt/Alia Bhatt_6.jpg
# /content/train/Alia Bhatt/Alia Bhatt_60.jpg
# /content/train/Alia Bhatt/Alia Bhatt_61.jpg
# /content/train/Alia Bhatt/Alia Bhatt_62.jpg
# /content/train/Alia Bhatt/Alia Bhatt_63.jpg
# /content/train/Alia Bhatt/Alia Bhatt_64.jpg
# /content/train/Alia Bhatt/Alia Bhatt_65.jpg
# /content/train/Alia Bhatt/Alia Bhatt_66.jpg
# /content/train/Alia Bhatt/Alia Bhatt_68.jpg
# /content/train/Alia Bhatt/Alia Bhatt_69.jpg
# /content/train/Alia Bhatt/Alia Bhatt_7.jpg
# /content/train/Alia Bhatt/Alia Bhatt_70.jpg
# /content/train/Alia Bhatt/Alia Bhatt_71.jpg
# /content/train/Alia Bhatt/Alia Bhatt_73.jpg
# /content/train/Alia Bhatt/Alia Bhatt_74.jpg
# /content/train/Alia Bhatt/Alia Bhatt_75.jpg
# /content/train/Alia Bhatt/Alia Bhatt_76.jpg
# /content/train/Alia Bhatt/Alia Bhatt_77.jpg
# /content/train/Alia Bhatt/Alia Bhatt_78.jpg
# /content/train/Amitabh Bachchan/Amitabh Bachchan_0.jpg
# /content/train/Amitabh Bachchan/Amitabh Bachchan_1.jpg
# /content/train/Amitabh Bachchan/Amitabh Bachchan_10.jpg
# /content/train/Amitabh Bachchan/Amitabh Bachchan_11.jpg
# /content/train/Amitabh Bachchan/Amitabh Bachchan_12.jpg
# /content/train/Amitabh Bachchan/Amitabh Bachchan_13.jpg
# /content/train/Amitabh Bachchan/Amitabh Bachchan_14.jpg
# /content/train/Amitabh Bachchan/Amitabh Bachchan_15.jpg
# /content/train/Amitabh Bachchan/Amitabh Bachchan_16.jpg
# /content/train/Amitabh Bachchan/Amitabh Bachchan_17.jpg
# /content/train/Amitabh Bachchan/Amitabh Bachchan_18.jpg
# /content/train/Amitabh Bachchan/Amitabh Bachchan_19.jpg
# /content/train/Amitabh Bachchan/Amitabh Bachchan_2.jpg
# /content/train/Amitabh Bachchan/Amitabh Bachchan_20.jpg
# /content/train/Amitabh Bachchan/Amitabh Bachchan_21.jpg
# /content/train/Amitabh Bachchan/Amitabh Bachchan_22.jpg
# Multiple faces detected for /content/train/Amitabh Bachchan/Amitabh Bachchan_22.jpg, taking one with highest probability
# /content/train/Amitabh Bachchan/Amitabh Bachchan_23.jpg
# /content/train/Amitabh Bachchan/Amitabh Bachchan_24.jpg
# /content/train/Amitabh Bachchan/Amitabh Bachchan_25.jpg
# /content/train/Amitabh Bachchan/Amitabh Bachchan_26.jpg
# /content/train/Amitabh Bachchan/Amitabh Bachchan_28.jpg
# /content/train/Amitabh Bachchan/Amitabh Bachchan_29.jpg
# /content/train/Amitabh Bachchan/Amitabh Bachchan_30.jpg
# /content/train/Amitabh Bachchan/Amitabh Bachchan_33.jpg
# /content/train/Amitabh Bachchan/Amitabh Bachchan_35.jpg
# /content/train/Amitabh Bachchan/Amitabh Bachchan_36.jpg
# /content/train/Amitabh Bachchan/Amitabh Bachchan_37.jpg
# /content/train/Amitabh Bachchan/Amitabh Bachchan_38.jpg
# Multiple faces detected for /content/train/Amitabh Bachchan/Amitabh Bachchan_38.jpg, taking one with highest probability
# /content/train/Amitabh Bachchan/Amitabh Bachchan_39.jpg
# /content/train/Amitabh Bachchan/Amitabh Bachchan_4.jpg
# /content/train/Amitabh Bachchan/Amitabh Bachchan_40.jpg
# /content/train/Amitabh Bachchan/Amitabh Bachchan_41.jpg
# /content/train/Amitabh Bachchan/Amitabh Bachchan_43.jpg
# Multiple faces detected for /content/train/Amitabh Bachchan/Amitabh Bachchan_43.jpg, taking one with highest probability
# /content/train/Amitabh Bachchan/Amitabh Bachchan_45.jpg
# /content/train/Amitabh Bachchan/Amitabh Bachchan_46.jpg
# /content/train/Amitabh Bachchan/Amitabh Bachchan_47.jpg
# /content/train/Amitabh Bachchan/Amitabh Bachchan_48.jpg
# /content/train/Amitabh Bachchan/Amitabh Bachchan_5.jpg
# /content/train/Amitabh Bachchan/Amitabh Bachchan_50.jpg
# /content/train/Amitabh Bachchan/Amitabh Bachchan_52.jpg
# /content/train/Amitabh Bachchan/Amitabh Bachchan_53.jpg
# /content/train/Amitabh Bachchan/Amitabh Bachchan_54.jpg
# /content/train/Amitabh Bachchan/Amitabh Bachchan_55.jpg
# /content/train/Amitabh Bachchan/Amitabh Bachchan_57.jpg
# /content/train/Amitabh Bachchan/Amitabh Bachchan_58.jpg
# /content/train/Amitabh Bachchan/Amitabh Bachchan_59.jpg
# /content/train/Amitabh Bachchan/Amitabh Bachchan_6.jpg
# /content/train/Amitabh Bachchan/Amitabh Bachchan_60.jpg
# /content/train/Amitabh Bachchan/Amitabh Bachchan_61.jpg
# /content/train/Amitabh Bachchan/Amitabh Bachchan_62.jpg
# /content/train/Amitabh Bachchan/Amitabh Bachchan_63.jpg
# /content/train/Amitabh Bachchan/Amitabh Bachchan_64.jpg
# /content/train/Amitabh Bachchan/Amitabh Bachchan_66.jpg
# /content/train/Amitabh Bachchan/Amitabh Bachchan_67.jpg
# /content/train/Amitabh Bachchan/Amitabh Bachchan_69.jpg
# /content/train/Amitabh Bachchan/Amitabh Bachchan_7.jpg
# /content/train/Amitabh Bachchan/Amitabh Bachchan_71.jpg
# /content/train/Amitabh Bachchan/Amitabh Bachchan_73.jpg
# /content/train/Amitabh Bachchan/Amitabh Bachchan_9.jpg
# /content/train/Andy Samberg/Andy Samberg_0.jpg
# /content/train/Andy Samberg/Andy Samberg_11.jpg
# /content/train/Andy Samberg/Andy Samberg_12.jpg
# /content/train/Andy Samberg/Andy Samberg_13.jpg
# /content/train/Andy Samberg/Andy Samberg_14.jpg
# /content/train/Andy Samberg/Andy Samberg_15.jpg
# /content/train/Andy Samberg/Andy Samberg_16.jpg
# /content/train/Andy Samberg/Andy Samberg_17.jpg
# /content/train/Andy Samberg/Andy Samberg_19.jpg
# /content/train/Andy Samberg/Andy Samberg_2.jpg
# /content/train/Andy Samberg/Andy Samberg_20.jpg
# /content/train/Andy Samberg/Andy Samberg_21.jpg
# /content/train/Andy Samberg/Andy Samberg_22.jpg
# /content/train/Andy Samberg/Andy Samberg_23.jpg
# /content/train/Andy Samberg/Andy Samberg_24.jpg
# /content/train/Andy Samberg/Andy Samberg_25.jpg
# /content/train/Andy Samberg/Andy Samberg_26.jpg
# /content/train/Andy Samberg/Andy Samberg_27.jpg
# /content/train/Andy Samberg/Andy Samberg_3.jpg
# /content/train/Andy Samberg/Andy Samberg_30.jpg
# /content/train/Andy Samberg/Andy Samberg_31.jpg
# /content/train/Andy Samberg/Andy Samberg_32.jpg
# /content/train/Andy Samberg/Andy Samberg_34.jpg
# /content/train/Andy Samberg/Andy Samberg_35.jpg
# /content/train/Andy Samberg/Andy Samberg_36.jpg
# /content/train/Andy Samberg/Andy Samberg_37.jpg
# /content/train/Andy Samberg/Andy Samberg_39.jpg
# /content/train/Andy Samberg/Andy Samberg_4.jpg
# /content/train/Andy Samberg/Andy Samberg_40.jpg
# /content/train/Andy Samberg/Andy Samberg_41.jpg
# /content/train/Andy Samberg/Andy Samberg_42.jpg
# /content/train/Andy Samberg/Andy Samberg_43.jpg
# /content/train/Andy Samberg/Andy Samberg_45.jpg
# /content/train/Andy Samberg/Andy Samberg_46.jpg
# /content/train/Andy Samberg/Andy Samberg_47.jpg
# /content/train/Andy Samberg/Andy Samberg_48.jpg
# /content/train/Andy Samberg/Andy Samberg_49.jpg
# /content/train/Andy Samberg/Andy Samberg_5.jpg
# /content/train/Andy Samberg/Andy Samberg_51.jpg
# /content/train/Andy Samberg/Andy Samberg_52.jpg
# /content/train/Andy Samberg/Andy Samberg_54.jpg
# /content/train/Andy Samberg/Andy Samberg_55.jpg
# /content/train/Andy Samberg/Andy Samberg_56.jpg
# /content/train/Andy Samberg/Andy Samberg_57.jpg
# /content/train/Andy Samberg/Andy Samberg_58.jpg
# /content/train/Andy Samberg/Andy Samberg_59.jpg
# /content/train/Andy Samberg/Andy Samberg_60.jpg
# /content/train/Andy Samberg/Andy Samberg_61.jpg
# Multiple faces detected for /content/train/Andy Samberg/Andy Samberg_61.jpg, taking one with highest probability
# /content/train/Andy Samberg/Andy Samberg_63.jpg
# /content/train/Andy Samberg/Andy Samberg_64.jpg
# /content/train/Andy Samberg/Andy Samberg_65.jpg
# /content/train/Andy Samberg/Andy Samberg_66.jpg
# /content/train/Andy Samberg/Andy Samberg_67.jpg
# /content/train/Andy Samberg/Andy Samberg_68.jpg
# /content/train/Andy Samberg/Andy Samberg_69.jpg
# /content/train/Andy Samberg/Andy Samberg_7.jpg
# Multiple faces detected for /content/train/Andy Samberg/Andy Samberg_7.jpg, taking one with highest probability
# /content/train/Andy Samberg/Andy Samberg_71.jpg
# /content/train/Andy Samberg/Andy Samberg_72.jpg
# /content/train/Andy Samberg/Andy Samberg_73.jpg
# /content/train/Andy Samberg/Andy Samberg_74.jpg
# /content/train/Andy Samberg/Andy Samberg_75.jpg
# /content/train/Andy Samberg/Andy Samberg_76.jpg
# /content/train/Andy Samberg/Andy Samberg_77.jpg
# /content/train/Andy Samberg/Andy Samberg_79.jpg
# /content/train/Andy Samberg/Andy Samberg_82.jpg
# /content/train/Andy Samberg/Andy Samberg_83.jpg
# /content/train/Andy Samberg/Andy Samberg_85.jpg
# /content/train/Andy Samberg/Andy Samberg_86.jpg
# /content/train/Andy Samberg/Andy Samberg_88.jpg
# /content/train/Andy Samberg/Andy Samberg_89.jpg
# /content/train/Andy Samberg/Andy Samberg_9.jpg
# /content/train/Andy Samberg/Andy Samberg_90.jpg
# /content/train/Andy Samberg/Andy Samberg_91.jpg
# /content/train/Anushka Sharma/Anushka Sharma_0.jpg
# /content/train/Anushka Sharma/Anushka Sharma_1.jpg
# /content/train/Anushka Sharma/Anushka Sharma_10.jpg
# /content/train/Anushka Sharma/Anushka Sharma_11.jpg
# /content/train/Anushka Sharma/Anushka Sharma_12.jpg
# /content/train/Anushka Sharma/Anushka Sharma_14.jpg
# /content/train/Anushka Sharma/Anushka Sharma_15.jpg
# /content/train/Anushka Sharma/Anushka Sharma_16.jpg
# /content/train/Anushka Sharma/Anushka Sharma_17.jpg
# /content/train/Anushka Sharma/Anushka Sharma_19.jpg
# /content/train/Anushka Sharma/Anushka Sharma_2.jpg
# /content/train/Anushka Sharma/Anushka Sharma_20.jpg
# /content/train/Anushka Sharma/Anushka Sharma_22.jpg
# /content/train/Anushka Sharma/Anushka Sharma_23.jpg
# /content/train/Anushka Sharma/Anushka Sharma_24.jpg
# /content/train/Anushka Sharma/Anushka Sharma_25.jpg
# /content/train/Anushka Sharma/Anushka Sharma_26.jpg
# /content/train/Anushka Sharma/Anushka Sharma_27.jpg
# /content/train/Anushka Sharma/Anushka Sharma_28.jpg
# /content/train/Anushka Sharma/Anushka Sharma_29.jpg
# /content/train/Anushka Sharma/Anushka Sharma_31.jpg
# Multiple faces detected for /content/train/Anushka Sharma/Anushka Sharma_31.jpg, taking one with highest probability
# /content/train/Anushka Sharma/Anushka Sharma_32.jpg
# /content/train/Anushka Sharma/Anushka Sharma_33.jpg
# /content/train/Anushka Sharma/Anushka Sharma_34.jpg
# /content/train/Anushka Sharma/Anushka Sharma_35.jpg
# /content/train/Anushka Sharma/Anushka Sharma_36.jpg
# /content/train/Anushka Sharma/Anushka Sharma_37.jpg
# Multiple faces detected for /content/train/Anushka Sharma/Anushka Sharma_37.jpg, taking one with highest probability
# /content/train/Anushka Sharma/Anushka Sharma_39.jpg
# /content/train/Anushka Sharma/Anushka Sharma_4.jpg
# /content/train/Anushka Sharma/Anushka Sharma_40.jpg
# /content/train/Anushka Sharma/Anushka Sharma_41.jpg
# /content/train/Anushka Sharma/Anushka Sharma_42.jpg
# /content/train/Anushka Sharma/Anushka Sharma_43.jpg
# /content/train/Anushka Sharma/Anushka Sharma_44.jpg
# /content/train/Anushka Sharma/Anushka Sharma_45.jpg
# /content/train/Anushka Sharma/Anushka Sharma_48.jpg
# /content/train/Anushka Sharma/Anushka Sharma_49.jpg
# /content/train/Anushka Sharma/Anushka Sharma_5.jpg
# /content/train/Anushka Sharma/Anushka Sharma_51.jpg
# /content/train/Anushka Sharma/Anushka Sharma_52.jpg
# /content/train/Anushka Sharma/Anushka Sharma_53.jpg
# /content/train/Anushka Sharma/Anushka Sharma_54.jpg
# /content/train/Anushka Sharma/Anushka Sharma_55.jpg
# /content/train/Anushka Sharma/Anushka Sharma_56.jpg
# /content/train/Anushka Sharma/Anushka Sharma_57.jpg
# /content/train/Anushka Sharma/Anushka Sharma_58.jpg
# Multiple faces detected for /content/train/Anushka Sharma/Anushka Sharma_58.jpg, taking one with highest probability
# /content/train/Anushka Sharma/Anushka Sharma_59.jpg
# /content/train/Anushka Sharma/Anushka Sharma_60.jpg
# /content/train/Anushka Sharma/Anushka Sharma_62.jpg
# /content/train/Anushka Sharma/Anushka Sharma_63.jpg
# Multiple faces detected for /content/train/Anushka Sharma/Anushka Sharma_63.jpg, taking one with highest probability
# /content/train/Anushka Sharma/Anushka Sharma_64.jpg
# /content/train/Anushka Sharma/Anushka Sharma_65.jpg
# /content/train/Anushka Sharma/Anushka Sharma_8.jpg
# /content/train/Anushka Sharma/Anushka Sharma_9.jpg
# /content/train/Billie Eilish/Billie Eilish_10.jpg
# /content/train/Billie Eilish/Billie Eilish_11.jpg
# /content/train/Billie Eilish/Billie Eilish_12.jpg
# /content/train/Billie Eilish/Billie Eilish_14.jpg
# /content/train/Billie Eilish/Billie Eilish_15.jpg
# Multiple faces detected for /content/train/Billie Eilish/Billie Eilish_15.jpg, taking one with highest probability
# /content/train/Billie Eilish/Billie Eilish_16.jpg
# /content/train/Billie Eilish/Billie Eilish_17.jpg
# /content/train/Billie Eilish/Billie Eilish_18.jpg
# /content/train/Billie Eilish/Billie Eilish_19.jpg
# /content/train/Billie Eilish/Billie Eilish_22.jpg
# Multiple faces detected for /content/train/Billie Eilish/Billie Eilish_22.jpg, taking one with highest probability
# /content/train/Billie Eilish/Billie Eilish_23.jpg
# /content/train/Billie Eilish/Billie Eilish_26.jpg
# /content/train/Billie Eilish/Billie Eilish_28.jpg
# /content/train/Billie Eilish/Billie Eilish_29.jpg
# /content/train/Billie Eilish/Billie Eilish_30.jpg
# /content/train/Billie Eilish/Billie Eilish_31.jpg
# Multiple faces detected for /content/train/Billie Eilish/Billie Eilish_31.jpg, taking one with highest probability
# /content/train/Billie Eilish/Billie Eilish_32.jpg
# /content/train/Billie Eilish/Billie Eilish_33.jpg
# Multiple faces detected for /content/train/Billie Eilish/Billie Eilish_33.jpg, taking one with highest probability
# /content/train/Billie Eilish/Billie Eilish_34.jpg
# /content/train/Billie Eilish/Billie Eilish_35.jpg
# /content/train/Billie Eilish/Billie Eilish_36.jpg
# /content/train/Billie Eilish/Billie Eilish_37.jpg
# /content/train/Billie Eilish/Billie Eilish_38.jpg
# /content/train/Billie Eilish/Billie Eilish_39.jpg
# /content/train/Billie Eilish/Billie Eilish_4.jpg
# /content/train/Billie Eilish/Billie Eilish_40.jpg
# /content/train/Billie Eilish/Billie Eilish_41.jpg
# /content/train/Billie Eilish/Billie Eilish_43.jpg
# /content/train/Billie Eilish/Billie Eilish_44.jpg
# /content/train/Billie Eilish/Billie Eilish_45.jpg
# /content/train/Billie Eilish/Billie Eilish_46.jpg
# /content/train/Billie Eilish/Billie Eilish_47.jpg
# /content/train/Billie Eilish/Billie Eilish_49.jpg
# /content/train/Billie Eilish/Billie Eilish_5.jpg
# /content/train/Billie Eilish/Billie Eilish_50.jpg
# /content/train/Billie Eilish/Billie Eilish_51.jpg
# /content/train/Billie Eilish/Billie Eilish_52.jpg
# /content/train/Billie Eilish/Billie Eilish_53.jpg
# /content/train/Billie Eilish/Billie Eilish_54.jpg
# /content/train/Billie Eilish/Billie Eilish_55.jpg
# /content/train/Billie Eilish/Billie Eilish_56.jpg
# /content/train/Billie Eilish/Billie Eilish_57.jpg
# Multiple faces detected for /content/train/Billie Eilish/Billie Eilish_57.jpg, taking one with highest probability
# /content/train/Billie Eilish/Billie Eilish_58.jpg
# /content/train/Billie Eilish/Billie Eilish_59.jpg
# /content/train/Billie Eilish/Billie Eilish_6.jpg
# /content/train/Billie Eilish/Billie Eilish_60.jpg
# /content/train/Billie Eilish/Billie Eilish_61.jpg
# /content/train/Billie Eilish/Billie Eilish_62.jpg
# /content/train/Billie Eilish/Billie Eilish_63.jpg
# /content/train/Billie Eilish/Billie Eilish_64.jpg
# /content/train/Billie Eilish/Billie Eilish_65.jpg
# /content/train/Billie Eilish/Billie Eilish_66.jpg
# /content/train/Billie Eilish/Billie Eilish_67.jpg
# /content/train/Billie Eilish/Billie Eilish_68.jpg
# /content/train/Billie Eilish/Billie Eilish_69.jpg
# /content/train/Billie Eilish/Billie Eilish_7.jpg
# /content/train/Billie Eilish/Billie Eilish_71.jpg
# /content/train/Billie Eilish/Billie Eilish_73.jpg
# /content/train/Billie Eilish/Billie Eilish_74.jpg
# /content/train/Billie Eilish/Billie Eilish_75.jpg
# /content/train/Billie Eilish/Billie Eilish_77.jpg
# /content/train/Billie Eilish/Billie Eilish_79.jpg
# /content/train/Billie Eilish/Billie Eilish_8.jpg
# /content/train/Billie Eilish/Billie Eilish_80.jpg
# Multiple faces detected for /content/train/Billie Eilish/Billie Eilish_80.jpg, taking one with highest probability
# /content/train/Billie Eilish/Billie Eilish_82.jpg
# /content/train/Billie Eilish/Billie Eilish_83.jpg
# /content/train/Billie Eilish/Billie Eilish_84.jpg
# /content/train/Billie Eilish/Billie Eilish_85.jpg
# /content/train/Billie Eilish/Billie Eilish_86.jpg
# /content/train/Billie Eilish/Billie Eilish_87.jpg
# /content/train/Billie Eilish/Billie Eilish_88.jpg
# /content/train/Billie Eilish/Billie Eilish_89.jpg
# /content/train/Billie Eilish/Billie Eilish_9.jpg
# /content/train/Billie Eilish/Billie Eilish_90.jpg
# /content/train/Billie Eilish/Billie Eilish_91.jpg
# /content/train/Billie Eilish/Billie Eilish_92.jpg
# /content/train/Billie Eilish/Billie Eilish_94.jpg
# /content/train/Billie Eilish/Billie Eilish_96.jpg
# /content/train/Brad Pitt/Brad Pitt_0.jpg
# /content/train/Brad Pitt/Brad Pitt_1.jpg
# /content/train/Brad Pitt/Brad Pitt_10.jpg
# /content/train/Brad Pitt/Brad Pitt_100.jpg
# /content/train/Brad Pitt/Brad Pitt_101.jpg
# /content/train/Brad Pitt/Brad Pitt_103.jpg
# /content/train/Brad Pitt/Brad Pitt_104.jpg
# /content/train/Brad Pitt/Brad Pitt_105.jpg
# /content/train/Brad Pitt/Brad Pitt_106.jpg
# /content/train/Brad Pitt/Brad Pitt_107.jpg
# /content/train/Brad Pitt/Brad Pitt_108.jpg
# /content/train/Brad Pitt/Brad Pitt_109.jpg
# /content/train/Brad Pitt/Brad Pitt_110.jpg
# /content/train/Brad Pitt/Brad Pitt_113.jpg
# /content/train/Brad Pitt/Brad Pitt_114.jpg
# /content/train/Brad Pitt/Brad Pitt_115.jpg
# /content/train/Brad Pitt/Brad Pitt_116.jpg
# /content/train/Brad Pitt/Brad Pitt_117.jpg
# /content/train/Brad Pitt/Brad Pitt_118.jpg
# /content/train/Brad Pitt/Brad Pitt_119.jpg
# /content/train/Brad Pitt/Brad Pitt_12.jpg
# /content/train/Brad Pitt/Brad Pitt_13.jpg
# /content/train/Brad Pitt/Brad Pitt_14.jpg
# /content/train/Brad Pitt/Brad Pitt_15.jpg
# /content/train/Brad Pitt/Brad Pitt_16.jpg
# /content/train/Brad Pitt/Brad Pitt_17.jpg
# /content/train/Brad Pitt/Brad Pitt_18.jpg
# /content/train/Brad Pitt/Brad Pitt_19.jpg
# /content/train/Brad Pitt/Brad Pitt_2.jpg
# /content/train/Brad Pitt/Brad Pitt_22.jpg
# /content/train/Brad Pitt/Brad Pitt_23.jpg
# /content/train/Brad Pitt/Brad Pitt_25.jpg
# /content/train/Brad Pitt/Brad Pitt_26.jpg
# /content/train/Brad Pitt/Brad Pitt_27.jpg
# /content/train/Brad Pitt/Brad Pitt_29.jpg
# /content/train/Brad Pitt/Brad Pitt_3.jpg
# /content/train/Brad Pitt/Brad Pitt_30.jpg
# /content/train/Brad Pitt/Brad Pitt_32.jpg
# /content/train/Brad Pitt/Brad Pitt_33.jpg
# /content/train/Brad Pitt/Brad Pitt_34.jpg
# /content/train/Brad Pitt/Brad Pitt_35.jpg
# /content/train/Brad Pitt/Brad Pitt_36.jpg
# /content/train/Brad Pitt/Brad Pitt_37.jpg
# /content/train/Brad Pitt/Brad Pitt_38.jpg
# /content/train/Brad Pitt/Brad Pitt_39.jpg
# /content/train/Brad Pitt/Brad Pitt_4.jpg
# /content/train/Brad Pitt/Brad Pitt_40.jpg
# /content/train/Brad Pitt/Brad Pitt_41.jpg
# /content/train/Brad Pitt/Brad Pitt_43.jpg
# /content/train/Brad Pitt/Brad Pitt_45.jpg
# /content/train/Brad Pitt/Brad Pitt_46.jpg
# /content/train/Brad Pitt/Brad Pitt_47.jpg
# Multiple faces detected for /content/train/Brad Pitt/Brad Pitt_47.jpg, taking one with highest probability
# /content/train/Brad Pitt/Brad Pitt_48.jpg
# /content/train/Brad Pitt/Brad Pitt_49.jpg
# /content/train/Brad Pitt/Brad Pitt_5.jpg
# /content/train/Brad Pitt/Brad Pitt_50.jpg
# Multiple faces detected for /content/train/Brad Pitt/Brad Pitt_50.jpg, taking one with highest probability
# /content/train/Brad Pitt/Brad Pitt_51.jpg
# /content/train/Brad Pitt/Brad Pitt_53.jpg
# /content/train/Brad Pitt/Brad Pitt_54.jpg
# /content/train/Brad Pitt/Brad Pitt_56.jpg
# /content/train/Brad Pitt/Brad Pitt_57.jpg
# /content/train/Brad Pitt/Brad Pitt_58.jpg
# /content/train/Brad Pitt/Brad Pitt_59.jpg
# /content/train/Brad Pitt/Brad Pitt_6.jpg
# /content/train/Brad Pitt/Brad Pitt_64.jpg
# /content/train/Brad Pitt/Brad Pitt_65.jpg
# /content/train/Brad Pitt/Brad Pitt_66.jpg
# /content/train/Brad Pitt/Brad Pitt_67.jpg
# /content/train/Brad Pitt/Brad Pitt_68.jpg
# /content/train/Brad Pitt/Brad Pitt_69.jpg
# /content/train/Brad Pitt/Brad Pitt_7.jpg
# /content/train/Brad Pitt/Brad Pitt_70.jpg
# /content/train/Brad Pitt/Brad Pitt_71.jpg
# /content/train/Brad Pitt/Brad Pitt_72.jpg
# /content/train/Brad Pitt/Brad Pitt_73.jpg
# /content/train/Brad Pitt/Brad Pitt_75.jpg
# /content/train/Brad Pitt/Brad Pitt_76.jpg
# /content/train/Brad Pitt/Brad Pitt_78.jpg
# /content/train/Brad Pitt/Brad Pitt_8.jpg
# /content/train/Brad Pitt/Brad Pitt_80.jpg
# /content/train/Brad Pitt/Brad Pitt_81.jpg
# /content/train/Brad Pitt/Brad Pitt_82.jpg
# Multiple faces detected for /content/train/Brad Pitt/Brad Pitt_82.jpg, taking one with highest probability
# /content/train/Brad Pitt/Brad Pitt_83.jpg
# /content/train/Brad Pitt/Brad Pitt_84.jpg
# /content/train/Brad Pitt/Brad Pitt_85.jpg
# /content/train/Brad Pitt/Brad Pitt_86.jpg
# /content/train/Brad Pitt/Brad Pitt_87.jpg
# /content/train/Brad Pitt/Brad Pitt_90.jpg
# /content/train/Brad Pitt/Brad Pitt_91.jpg
# /content/train/Brad Pitt/Brad Pitt_92.jpg
# /content/train/Brad Pitt/Brad Pitt_93.jpg
# /content/train/Brad Pitt/Brad Pitt_94.jpg
# /content/train/Brad Pitt/Brad Pitt_95.jpg
# /content/train/Brad Pitt/Brad Pitt_96.jpg
# /content/train/Brad Pitt/Brad Pitt_97.jpg
# /content/train/Brad Pitt/Brad Pitt_98.jpg
# /content/train/Camila Cabello/Camila Cabello_10.jpg
# /content/train/Camila Cabello/Camila Cabello_11.jpg
# /content/train/Camila Cabello/Camila Cabello_12.jpg
# /content/train/Camila Cabello/Camila Cabello_13.jpg
# /content/train/Camila Cabello/Camila Cabello_15.jpg
# /content/train/Camila Cabello/Camila Cabello_16.jpg
# /content/train/Camila Cabello/Camila Cabello_18.jpg
# /content/train/Camila Cabello/Camila Cabello_19.jpg
# Multiple faces detected for /content/train/Camila Cabello/Camila Cabello_19.jpg, taking one with highest probability
# /content/train/Camila Cabello/Camila Cabello_2.jpg
# Multiple faces detected for /content/train/Camila Cabello/Camila Cabello_2.jpg, taking one with highest probability
# /content/train/Camila Cabello/Camila Cabello_20.jpg
# /content/train/Camila Cabello/Camila Cabello_21.jpg
# /content/train/Camila Cabello/Camila Cabello_23.jpg
# /content/train/Camila Cabello/Camila Cabello_24.jpg
# /content/train/Camila Cabello/Camila Cabello_25.jpg
# /content/train/Camila Cabello/Camila Cabello_27.jpg
# /content/train/Camila Cabello/Camila Cabello_28.jpg
# /content/train/Camila Cabello/Camila Cabello_29.jpg
# /content/train/Camila Cabello/Camila Cabello_3.jpg
# /content/train/Camila Cabello/Camila Cabello_30.jpg
# /content/train/Camila Cabello/Camila Cabello_31.jpg
# /content/train/Camila Cabello/Camila Cabello_32.jpg
# /content/train/Camila Cabello/Camila Cabello_33.jpg
# /content/train/Camila Cabello/Camila Cabello_34.jpg
# /content/train/Camila Cabello/Camila Cabello_38.jpg
# /content/train/Camila Cabello/Camila Cabello_39.jpg
# /content/train/Camila Cabello/Camila Cabello_4.jpg
# Multiple faces detected for /content/train/Camila Cabello/Camila Cabello_4.jpg, taking one with highest probability
# /content/train/Camila Cabello/Camila Cabello_41.jpg
# /content/train/Camila Cabello/Camila Cabello_42.jpg
# /content/train/Camila Cabello/Camila Cabello_44.jpg
# /content/train/Camila Cabello/Camila Cabello_46.jpg
# /content/train/Camila Cabello/Camila Cabello_47.jpg
# /content/train/Camila Cabello/Camila Cabello_48.jpg
# /content/train/Camila Cabello/Camila Cabello_49.jpg
# /content/train/Camila Cabello/Camila Cabello_5.jpg
# /content/train/Camila Cabello/Camila Cabello_50.jpg
# /content/train/Camila Cabello/Camila Cabello_51.jpg
# /content/train/Camila Cabello/Camila Cabello_52.jpg
# /content/train/Camila Cabello/Camila Cabello_53.jpg
# /content/train/Camila Cabello/Camila Cabello_54.jpg
# /content/train/Camila Cabello/Camila Cabello_55.jpg
# /content/train/Camila Cabello/Camila Cabello_56.jpg
# /content/train/Camila Cabello/Camila Cabello_58.jpg
# /content/train/Camila Cabello/Camila Cabello_59.jpg
# /content/train/Camila Cabello/Camila Cabello_6.jpg
# /content/train/Camila Cabello/Camila Cabello_60.jpg
# /content/train/Camila Cabello/Camila Cabello_61.jpg
# /content/train/Camila Cabello/Camila Cabello_62.jpg
# /content/train/Camila Cabello/Camila Cabello_63.jpg
# /content/train/Camila Cabello/Camila Cabello_64.jpg
# Multiple faces detected for /content/train/Camila Cabello/Camila Cabello_64.jpg, taking one with highest probability
# /content/train/Camila Cabello/Camila Cabello_66.jpg
# /content/train/Camila Cabello/Camila Cabello_67.jpg
# /content/train/Camila Cabello/Camila Cabello_68.jpg
# /content/train/Camila Cabello/Camila Cabello_70.jpg
# /content/train/Camila Cabello/Camila Cabello_71.jpg
# /content/train/Camila Cabello/Camila Cabello_72.jpg
# /content/train/Camila Cabello/Camila Cabello_73.jpg
# Multiple faces detected for /content/train/Camila Cabello/Camila Cabello_73.jpg, taking one with highest probability
# /content/train/Camila Cabello/Camila Cabello_74.jpg
# /content/train/Camila Cabello/Camila Cabello_76.jpg
# /content/train/Camila Cabello/Camila Cabello_77.jpg
# /content/train/Camila Cabello/Camila Cabello_78.jpg
# /content/train/Camila Cabello/Camila Cabello_79.jpg
# /content/train/Camila Cabello/Camila Cabello_8.jpg
# /content/train/Camila Cabello/Camila Cabello_81.jpg
# /content/train/Camila Cabello/Camila Cabello_82.jpg
# /content/train/Camila Cabello/Camila Cabello_83.jpg
# /content/train/Camila Cabello/Camila Cabello_84.jpg
# /content/train/Camila Cabello/Camila Cabello_85.jpg
# /content/train/Camila Cabello/Camila Cabello_86.jpg
# /content/train/Camila Cabello/Camila Cabello_9.jpg
# /content/train/Charlize Theron/Charlize Theron_0.jpg
# /content/train/Charlize Theron/Charlize Theron_1.jpg
# /content/train/Charlize Theron/Charlize Theron_10.jpg
# /content/train/Charlize Theron/Charlize Theron_11.jpg
# /content/train/Charlize Theron/Charlize Theron_13.jpg
# /content/train/Charlize Theron/Charlize Theron_14.jpg
# /content/train/Charlize Theron/Charlize Theron_15.jpg
# /content/train/Charlize Theron/Charlize Theron_16.jpg
# /content/train/Charlize Theron/Charlize Theron_18.jpg
# /content/train/Charlize Theron/Charlize Theron_19.jpg
# /content/train/Charlize Theron/Charlize Theron_2.jpg
# /content/train/Charlize Theron/Charlize Theron_20.jpg
# /content/train/Charlize Theron/Charlize Theron_21.jpg
# /content/train/Charlize Theron/Charlize Theron_22.jpg
# /content/train/Charlize Theron/Charlize Theron_24.jpg
# /content/train/Charlize Theron/Charlize Theron_25.jpg
# /content/train/Charlize Theron/Charlize Theron_28.jpg
# /content/train/Charlize Theron/Charlize Theron_29.jpg
# /content/train/Charlize Theron/Charlize Theron_3.jpg
# /content/train/Charlize Theron/Charlize Theron_30.jpg
# /content/train/Charlize Theron/Charlize Theron_31.jpg
# /content/train/Charlize Theron/Charlize Theron_33.jpg
# /content/train/Charlize Theron/Charlize Theron_34.jpg
# /content/train/Charlize Theron/Charlize Theron_36.jpg
# /content/train/Charlize Theron/Charlize Theron_37.jpg
# /content/train/Charlize Theron/Charlize Theron_38.jpg
# /content/train/Charlize Theron/Charlize Theron_39.jpg
# /content/train/Charlize Theron/Charlize Theron_4.jpg
# /content/train/Charlize Theron/Charlize Theron_41.jpg
# /content/train/Charlize Theron/Charlize Theron_42.jpg
# /content/train/Charlize Theron/Charlize Theron_43.jpg
# /content/train/Charlize Theron/Charlize Theron_44.jpg
# /content/train/Charlize Theron/Charlize Theron_45.jpg
# /content/train/Charlize Theron/Charlize Theron_46.jpg
# Multiple faces detected for /content/train/Charlize Theron/Charlize Theron_46.jpg, taking one with highest probability
# /content/train/Charlize Theron/Charlize Theron_47.jpg
# /content/train/Charlize Theron/Charlize Theron_48.jpg
# /content/train/Charlize Theron/Charlize Theron_49.jpg
# Multiple faces detected for /content/train/Charlize Theron/Charlize Theron_49.jpg, taking one with highest probability
# /content/train/Charlize Theron/Charlize Theron_5.jpg
# /content/train/Charlize Theron/Charlize Theron_50.jpg
# /content/train/Charlize Theron/Charlize Theron_51.jpg
# /content/train/Charlize Theron/Charlize Theron_53.jpg
# /content/train/Charlize Theron/Charlize Theron_54.jpg
# /content/train/Charlize Theron/Charlize Theron_55.jpg
# /content/train/Charlize Theron/Charlize Theron_56.jpg
# /content/train/Charlize Theron/Charlize Theron_57.jpg
# /content/train/Charlize Theron/Charlize Theron_59.jpg
# /content/train/Charlize Theron/Charlize Theron_6.jpg
# /content/train/Charlize Theron/Charlize Theron_60.jpg
# /content/train/Charlize Theron/Charlize Theron_61.jpg
# /content/train/Charlize Theron/Charlize Theron_62.jpg
# /content/train/Charlize Theron/Charlize Theron_65.jpg
# /content/train/Charlize Theron/Charlize Theron_66.jpg
# /content/train/Charlize Theron/Charlize Theron_69.jpg
# /content/train/Charlize Theron/Charlize Theron_7.jpg
# /content/train/Charlize Theron/Charlize Theron_70.jpg
# /content/train/Charlize Theron/Charlize Theron_71.jpg
# /content/train/Charlize Theron/Charlize Theron_72.jpg
# /content/train/Charlize Theron/Charlize Theron_73.jpg
# /content/train/Charlize Theron/Charlize Theron_75.jpg
# /content/train/Charlize Theron/Charlize Theron_77.jpg
# /content/train/Charlize Theron/Charlize Theron_8.jpg
# /content/train/Charlize Theron/Charlize Theron_9.jpg
# /content/train/Claire Holt/Claire Holt_0.jpg
# /content/train/Claire Holt/Claire Holt_1.jpg
# /content/train/Claire Holt/Claire Holt_10.jpg
# /content/train/Claire Holt/Claire Holt_11.jpg
# /content/train/Claire Holt/Claire Holt_13.jpg
# /content/train/Claire Holt/Claire Holt_14.jpg
# /content/train/Claire Holt/Claire Holt_15.jpg
# /content/train/Claire Holt/Claire Holt_16.jpg
# /content/train/Claire Holt/Claire Holt_17.jpg
# /content/train/Claire Holt/Claire Holt_18.jpg
# /content/train/Claire Holt/Claire Holt_2.jpg
# /content/train/Claire Holt/Claire Holt_20.jpg
# /content/train/Claire Holt/Claire Holt_21.jpg
# /content/train/Claire Holt/Claire Holt_23.jpg
# /content/train/Claire Holt/Claire Holt_24.jpg
# /content/train/Claire Holt/Claire Holt_25.jpg
# /content/train/Claire Holt/Claire Holt_26.jpg
# /content/train/Claire Holt/Claire Holt_27.jpg
# /content/train/Claire Holt/Claire Holt_28.jpg
# /content/train/Claire Holt/Claire Holt_29.jpg
# /content/train/Claire Holt/Claire Holt_3.jpg
# /content/train/Claire Holt/Claire Holt_30.jpg
# /content/train/Claire Holt/Claire Holt_31.jpg
# /content/train/Claire Holt/Claire Holt_32.jpg
# /content/train/Claire Holt/Claire Holt_33.jpg
# /content/train/Claire Holt/Claire Holt_34.jpg
# /content/train/Claire Holt/Claire Holt_37.jpg
# Multiple faces detected for /content/train/Claire Holt/Claire Holt_37.jpg, taking one with highest probability
# /content/train/Claire Holt/Claire Holt_38.jpg
# /content/train/Claire Holt/Claire Holt_39.jpg
# /content/train/Claire Holt/Claire Holt_42.jpg
# /content/train/Claire Holt/Claire Holt_43.jpg
# /content/train/Claire Holt/Claire Holt_44.jpg
# /content/train/Claire Holt/Claire Holt_45.jpg
# /content/train/Claire Holt/Claire Holt_47.jpg
# /content/train/Claire Holt/Claire Holt_48.jpg
# /content/train/Claire Holt/Claire Holt_49.jpg
# /content/train/Claire Holt/Claire Holt_5.jpg
# /content/train/Claire Holt/Claire Holt_51.jpg
# /content/train/Claire Holt/Claire Holt_52.jpg
# /content/train/Claire Holt/Claire Holt_53.jpg
# /content/train/Claire Holt/Claire Holt_54.jpg
# /content/train/Claire Holt/Claire Holt_55.jpg
# /content/train/Claire Holt/Claire Holt_56.jpg
# /content/train/Claire Holt/Claire Holt_58.jpg
# /content/train/Claire Holt/Claire Holt_59.jpg
# /content/train/Claire Holt/Claire Holt_6.jpg
# /content/train/Claire Holt/Claire Holt_60.jpg
# /content/train/Claire Holt/Claire Holt_61.jpg
# /content/train/Claire Holt/Claire Holt_62.jpg
# /content/train/Claire Holt/Claire Holt_63.jpg
# /content/train/Claire Holt/Claire Holt_64.jpg
# /content/train/Claire Holt/Claire Holt_65.jpg
# /content/train/Claire Holt/Claire Holt_66.jpg
# /content/train/Claire Holt/Claire Holt_67.jpg
# /content/train/Claire Holt/Claire Holt_69.jpg
# /content/train/Claire Holt/Claire Holt_7.jpg
# /content/train/Claire Holt/Claire Holt_70.jpg
# /content/train/Claire Holt/Claire Holt_74.jpg
# /content/train/Claire Holt/Claire Holt_75.jpg
# /content/train/Claire Holt/Claire Holt_76.jpg
# /content/train/Claire Holt/Claire Holt_77.jpg
# /content/train/Claire Holt/Claire Holt_78.jpg
# /content/train/Claire Holt/Claire Holt_79.jpg
# /content/train/Claire Holt/Claire Holt_8.jpg
# /content/train/Claire Holt/Claire Holt_80.jpg
# /content/train/Claire Holt/Claire Holt_82.jpg
# /content/train/Claire Holt/Claire Holt_84.jpg
# Multiple faces detected for /content/train/Claire Holt/Claire Holt_84.jpg, taking one with highest probability
# /content/train/Claire Holt/Claire Holt_85.jpg
# /content/train/Claire Holt/Claire Holt_86.jpg
# /content/train/Claire Holt/Claire Holt_88.jpg
# /content/train/Claire Holt/Claire Holt_9.jpg
# /content/train/Claire Holt/Claire Holt_90.jpg
# Multiple faces detected for /content/train/Claire Holt/Claire Holt_90.jpg, taking one with highest probability
# /content/train/Claire Holt/Claire Holt_91.jpg
# /content/train/Claire Holt/Claire Holt_92.jpg
# /content/train/Claire Holt/Claire Holt_93.jpg
# /content/train/Claire Holt/Claire Holt_94.jpg
# /content/train/Courtney Cox/Courtney Cox_0.jpg
# /content/train/Courtney Cox/Courtney Cox_10.jpg
# /content/train/Courtney Cox/Courtney Cox_11.jpg
# /content/train/Courtney Cox/Courtney Cox_12.jpg
# /content/train/Courtney Cox/Courtney Cox_13.jpg
# /content/train/Courtney Cox/Courtney Cox_16.jpg
# /content/train/Courtney Cox/Courtney Cox_17.jpg
# /content/train/Courtney Cox/Courtney Cox_18.jpg
# /content/train/Courtney Cox/Courtney Cox_2.jpg
# /content/train/Courtney Cox/Courtney Cox_20.jpg
# /content/train/Courtney Cox/Courtney Cox_21.jpg
# /content/train/Courtney Cox/Courtney Cox_23.jpg
# /content/train/Courtney Cox/Courtney Cox_25.jpg
# /content/train/Courtney Cox/Courtney Cox_26.jpg
# /content/train/Courtney Cox/Courtney Cox_27.jpg
# /content/train/Courtney Cox/Courtney Cox_28.jpg
# /content/train/Courtney Cox/Courtney Cox_29.jpg
# /content/train/Courtney Cox/Courtney Cox_3.jpg
# /content/train/Courtney Cox/Courtney Cox_30.jpg
# /content/train/Courtney Cox/Courtney Cox_31.jpg
# /content/train/Courtney Cox/Courtney Cox_32.jpg
# /content/train/Courtney Cox/Courtney Cox_33.jpg
# /content/train/Courtney Cox/Courtney Cox_35.jpg
# /content/train/Courtney Cox/Courtney Cox_36.jpg
# /content/train/Courtney Cox/Courtney Cox_37.jpg
# /content/train/Courtney Cox/Courtney Cox_38.jpg
# /content/train/Courtney Cox/Courtney Cox_39.jpg
# /content/train/Courtney Cox/Courtney Cox_4.jpg
# /content/train/Courtney Cox/Courtney Cox_40.jpg
# /content/train/Courtney Cox/Courtney Cox_41.jpg
# /content/train/Courtney Cox/Courtney Cox_42.jpg
# /content/train/Courtney Cox/Courtney Cox_43.jpg
# /content/train/Courtney Cox/Courtney Cox_44.jpg
# /content/train/Courtney Cox/Courtney Cox_45.jpg
# /content/train/Courtney Cox/Courtney Cox_46.jpg
# /content/train/Courtney Cox/Courtney Cox_47.jpg
# /content/train/Courtney Cox/Courtney Cox_49.jpg
# /content/train/Courtney Cox/Courtney Cox_5.jpg
# /content/train/Courtney Cox/Courtney Cox_50.jpg
# /content/train/Courtney Cox/Courtney Cox_51.jpg
# Multiple faces detected for /content/train/Courtney Cox/Courtney Cox_51.jpg, taking one with highest probability
# /content/train/Courtney Cox/Courtney Cox_52.jpg
# /content/train/Courtney Cox/Courtney Cox_53.jpg
# /content/train/Courtney Cox/Courtney Cox_54.jpg
# /content/train/Courtney Cox/Courtney Cox_55.jpg
# /content/train/Courtney Cox/Courtney Cox_57.jpg
# Multiple faces detected for /content/train/Courtney Cox/Courtney Cox_57.jpg, taking one with highest probability
# /content/train/Courtney Cox/Courtney Cox_59.jpg
# /content/train/Courtney Cox/Courtney Cox_6.jpg
# /content/train/Courtney Cox/Courtney Cox_60.jpg
# /content/train/Courtney Cox/Courtney Cox_61.jpg
# /content/train/Courtney Cox/Courtney Cox_62.jpg
# /content/train/Courtney Cox/Courtney Cox_63.jpg
# /content/train/Courtney Cox/Courtney Cox_65.jpg
# /content/train/Courtney Cox/Courtney Cox_66.jpg
# Multiple faces detected for /content/train/Courtney Cox/Courtney Cox_66.jpg, taking one with highest probability
# /content/train/Courtney Cox/Courtney Cox_67.jpg
# /content/train/Courtney Cox/Courtney Cox_69.jpg
# /content/train/Courtney Cox/Courtney Cox_7.jpg
# /content/train/Courtney Cox/Courtney Cox_70.jpg
# /content/train/Courtney Cox/Courtney Cox_71.jpg
# /content/train/Courtney Cox/Courtney Cox_72.jpg
# /content/train/Courtney Cox/Courtney Cox_73.jpg
# /content/train/Courtney Cox/Courtney Cox_75.jpg
# /content/train/Courtney Cox/Courtney Cox_77.jpg
# /content/train/Courtney Cox/Courtney Cox_79.jpg
# /content/train/Courtney Cox/Courtney Cox_8.jpg
# /content/train/Dwayne Johnson/Dwayne Johnson_0.jpg
# /content/train/Dwayne Johnson/Dwayne Johnson_1.jpg
# /content/train/Dwayne Johnson/Dwayne Johnson_10.jpg
# /content/train/Dwayne Johnson/Dwayne Johnson_11.jpg
# /content/train/Dwayne Johnson/Dwayne Johnson_13.jpg
# /content/train/Dwayne Johnson/Dwayne Johnson_15.jpg
# /content/train/Dwayne Johnson/Dwayne Johnson_17.jpg
# /content/train/Dwayne Johnson/Dwayne Johnson_18.jpg
# /content/train/Dwayne Johnson/Dwayne Johnson_2.jpg
# /content/train/Dwayne Johnson/Dwayne Johnson_20.jpg
# /content/train/Dwayne Johnson/Dwayne Johnson_21.jpg
# /content/train/Dwayne Johnson/Dwayne Johnson_22.jpg
# /content/train/Dwayne Johnson/Dwayne Johnson_23.jpg
# /content/train/Dwayne Johnson/Dwayne Johnson_26.jpg
# /content/train/Dwayne Johnson/Dwayne Johnson_28.jpg
# /content/train/Dwayne Johnson/Dwayne Johnson_29.jpg
# /content/train/Dwayne Johnson/Dwayne Johnson_3.jpg
# /content/train/Dwayne Johnson/Dwayne Johnson_31.jpg
# /content/train/Dwayne Johnson/Dwayne Johnson_32.jpg
# Multiple faces detected for /content/train/Dwayne Johnson/Dwayne Johnson_32.jpg, taking one with highest probability
# /content/train/Dwayne Johnson/Dwayne Johnson_33.jpg
# /content/train/Dwayne Johnson/Dwayne Johnson_34.jpg
# /content/train/Dwayne Johnson/Dwayne Johnson_35.jpg
# /content/train/Dwayne Johnson/Dwayne Johnson_36.jpg
# /content/train/Dwayne Johnson/Dwayne Johnson_37.jpg
# /content/train/Dwayne Johnson/Dwayne Johnson_38.jpg
# /content/train/Dwayne Johnson/Dwayne Johnson_39.jpg
# /content/train/Dwayne Johnson/Dwayne Johnson_4.jpg
# /content/train/Dwayne Johnson/Dwayne Johnson_40.jpg
# /content/train/Dwayne Johnson/Dwayne Johnson_41.jpg
# /content/train/Dwayne Johnson/Dwayne Johnson_43.jpg
# Multiple faces detected for /content/train/Dwayne Johnson/Dwayne Johnson_43.jpg, taking one with highest probability
# /content/train/Dwayne Johnson/Dwayne Johnson_44.jpg
# /content/train/Dwayne Johnson/Dwayne Johnson_45.jpg
# Multiple faces detected for /content/train/Dwayne Johnson/Dwayne Johnson_45.jpg, taking one with highest probability
# /content/train/Dwayne Johnson/Dwayne Johnson_46.jpg
# /content/train/Dwayne Johnson/Dwayne Johnson_47.jpg
# /content/train/Dwayne Johnson/Dwayne Johnson_48.jpg
# /content/train/Dwayne Johnson/Dwayne Johnson_49.jpg
# /content/train/Dwayne Johnson/Dwayne Johnson_5.jpg
# /content/train/Dwayne Johnson/Dwayne Johnson_50.jpg
# /content/train/Dwayne Johnson/Dwayne Johnson_51.jpg
# /content/train/Dwayne Johnson/Dwayne Johnson_53.jpg
# /content/train/Dwayne Johnson/Dwayne Johnson_54.jpg
# /content/train/Dwayne Johnson/Dwayne Johnson_55.jpg
# /content/train/Dwayne Johnson/Dwayne Johnson_56.jpg
# /content/train/Dwayne Johnson/Dwayne Johnson_58.jpg
# /content/train/Dwayne Johnson/Dwayne Johnson_59.jpg
# /content/train/Dwayne Johnson/Dwayne Johnson_60.jpg
# /content/train/Dwayne Johnson/Dwayne Johnson_7.jpg
# /content/train/Dwayne Johnson/Dwayne Johnson_8.jpg
# /content/train/Elizabeth Olsen/Elizabeth Olsen_0.jpg
# /content/train/Elizabeth Olsen/Elizabeth Olsen_1.jpg
# /content/train/Elizabeth Olsen/Elizabeth Olsen_10.jpg
# /content/train/Elizabeth Olsen/Elizabeth Olsen_11.jpg
# /content/train/Elizabeth Olsen/Elizabeth Olsen_12.jpg
# /content/train/Elizabeth Olsen/Elizabeth Olsen_13.jpg
# /content/train/Elizabeth Olsen/Elizabeth Olsen_14.jpg
# Multiple faces detected for /content/train/Elizabeth Olsen/Elizabeth Olsen_14.jpg, taking one with highest probability
# ...
# /content/val/Elizabeth Olsen/Elizabeth Olsen_30.jpg
# /content/val/Elizabeth Olsen/Elizabeth Olsen_32.jpg
# /content/val/Elizabeth Olsen/Elizabeth Olsen_4.jpg
# /content/val/Elizabeth Olsen/Elizabeth Olsen_41.jpg
# /content/val/Elizabeth Olsen/Elizabeth Olsen_43.jpg
# /content/val/Elizabeth Olsen/Elizabeth Olsen_47.jpg
# /content/val/Elizabeth Olsen/Elizabeth Olsen_53.jpg
# /content/val/Elizabeth Olsen/Elizabeth Olsen_55.jpg
# /content/val/Elizabeth Olsen/Elizabeth Olsen_56.jpg
# /content/val/Elizabeth Olsen/Elizabeth Olsen_6.jpg
# /content/val/Elizabeth Olsen/Elizabeth Olsen_62.jpg
# /content/val/Elizabeth Olsen/Elizabeth Olsen_64.jpg
# /content/val/Elizabeth Olsen/Elizabeth Olsen_66.jpg
# /content/val/Elizabeth Olsen/Elizabeth Olsen_8.jpg
# /content/val/Elizabeth Olsen/Elizabeth Olsen_9.jpg
# /content/val/Ellen Degeneres/Ellen Degeneres_14.jpg
# /content/val/Ellen Degeneres/Ellen Degeneres_2.jpg
# /content/val/Ellen Degeneres/Ellen Degeneres_24.jpg
# /content/val/Ellen Degeneres/Ellen Degeneres_25.jpg
# /content/val/Ellen Degeneres/Ellen Degeneres_31.jpg
# /content/val/Ellen Degeneres/Ellen Degeneres_35.jpg
# /content/val/Ellen Degeneres/Ellen Degeneres_47.jpg
# /content/val/Ellen Degeneres/Ellen Degeneres_50.jpg
# /content/val/Ellen Degeneres/Ellen Degeneres_52.jpg
# /content/val/Ellen Degeneres/Ellen Degeneres_60.jpg
# /content/val/Ellen Degeneres/Ellen Degeneres_66.jpg
# /content/val/Ellen Degeneres/Ellen Degeneres_67.jpg
# /content/val/Ellen Degeneres/Ellen Degeneres_70.jpg
# /content/val/Ellen Degeneres/Ellen Degeneres_71.jpg
# /content/val/Ellen Degeneres/Ellen Degeneres_8.jpg
# /content/val/Henry Cavill/Henry Cavill_1.jpg
# /content/val/Henry Cavill/Henry Cavill_102.jpg
# /content/val/Henry Cavill/Henry Cavill_103.jpg
# /content/val/Henry Cavill/Henry Cavill_105.jpg
# /content/val/Henry Cavill/Henry Cavill_27.jpg
# /content/val/Henry Cavill/Henry Cavill_28.jpg
# /content/val/Henry Cavill/Henry Cavill_29.jpg
# /content/val/Henry Cavill/Henry Cavill_31.jpg
# /content/val/Henry Cavill/Henry Cavill_38.jpg
# /content/val/Henry Cavill/Henry Cavill_40.jpg
# /content/val/Henry Cavill/Henry Cavill_44.jpg
# /content/val/Henry Cavill/Henry Cavill_61.jpg
# /content/val/Henry Cavill/Henry Cavill_66.jpg
# /content/val/Henry Cavill/Henry Cavill_72.jpg
# /content/val/Henry Cavill/Henry Cavill_80.jpg
# /content/val/Henry Cavill/Henry Cavill_83.jpg
# /content/val/Henry Cavill/Henry Cavill_88.jpg
# /content/val/Henry Cavill/Henry Cavill_90.jpg
# /content/val/Henry Cavill/Henry Cavill_91.jpg
# /content/val/Henry Cavill/Henry Cavill_93.jpg
# /content/val/Henry Cavill/Henry Cavill_95.jpg
# /content/val/Henry Cavill/Henry Cavill_97.jpg
# /content/val/Hrithik Roshan/Hrithik Roshan_1.jpg
# /content/val/Hrithik Roshan/Hrithik Roshan_10.jpg
# /content/val/Hrithik Roshan/Hrithik Roshan_14.jpg
# /content/val/Hrithik Roshan/Hrithik Roshan_16.jpg
# /content/val/Hrithik Roshan/Hrithik Roshan_33.jpg
# /content/val/Hrithik Roshan/Hrithik Roshan_37.jpg
# /content/val/Hrithik Roshan/Hrithik Roshan_4.jpg
# /content/val/Hrithik Roshan/Hrithik Roshan_47.jpg
# /content/val/Hrithik Roshan/Hrithik Roshan_51.jpg
# /content/val/Hrithik Roshan/Hrithik Roshan_57.jpg
# /content/val/Hrithik Roshan/Hrithik Roshan_60.jpg
# /content/val/Hrithik Roshan/Hrithik Roshan_7.jpg
# /content/val/Hrithik Roshan/Hrithik Roshan_8.jpg
# /content/val/Hrithik Roshan/Hrithik Roshan_82.jpg
# /content/val/Hrithik Roshan/Hrithik Roshan_84.jpg
# /content/val/Hrithik Roshan/Hrithik Roshan_86.jpg
# /content/val/Hrithik Roshan/Hrithik Roshan_90.jpg
# /content/val/Hrithik Roshan/Hrithik Roshan_91.jpg
# /content/val/Hrithik Roshan/Hrithik Roshan_96.jpg
# /content/val/Hrithik Roshan/Hrithik Roshan_98.jpg
# /content/val/Hrithik Roshan/Hrithik Roshan_99.jpg
# /content/val/Hugh Jackman/Hugh Jackman_101.jpg
# /content/val/Hugh Jackman/Hugh Jackman_103.jpg
# /content/val/Hugh Jackman/Hugh Jackman_104.jpg
# /content/val/Hugh Jackman/Hugh Jackman_106.jpg
# /content/val/Hugh Jackman/Hugh Jackman_108.jpg
# /content/val/Hugh Jackman/Hugh Jackman_110.jpg
# /content/val/Hugh Jackman/Hugh Jackman_111.jpg
# /content/val/Hugh Jackman/Hugh Jackman_17.jpg
# /content/val/Hugh Jackman/Hugh Jackman_20.jpg
# /content/val/Hugh Jackman/Hugh Jackman_21.jpg
# /content/val/Hugh Jackman/Hugh Jackman_24.jpg
# /content/val/Hugh Jackman/Hugh Jackman_3.jpg
# /content/val/Hugh Jackman/Hugh Jackman_30.jpg
# /content/val/Hugh Jackman/Hugh Jackman_32.jpg
# /content/val/Hugh Jackman/Hugh Jackman_33.jpg
# /content/val/Hugh Jackman/Hugh Jackman_36.jpg
# /content/val/Hugh Jackman/Hugh Jackman_47.jpg
# Multiple faces detected for /content/val/Hugh Jackman/Hugh Jackman_47.jpg, taking one with highest probability
# /content/val/Hugh Jackman/Hugh Jackman_63.jpg
# /content/val/Hugh Jackman/Hugh Jackman_65.jpg
# /content/val/Hugh Jackman/Hugh Jackman_75.jpg
# /content/val/Hugh Jackman/Hugh Jackman_76.jpg
# /content/val/Hugh Jackman/Hugh Jackman_77.jpg
# /content/val/Hugh Jackman/Hugh Jackman_81.jpg
# /content/val/Jessica Alba/Jessica Alba_106.jpg
# /content/val/Jessica Alba/Jessica Alba_13.jpg
# /content/val/Jessica Alba/Jessica Alba_2.jpg
# /content/val/Jessica Alba/Jessica Alba_22.jpg
# /content/val/Jessica Alba/Jessica Alba_26.jpg
# /content/val/Jessica Alba/Jessica Alba_28.jpg
# /content/val/Jessica Alba/Jessica Alba_29.jpg
# /content/val/Jessica Alba/Jessica Alba_31.jpg
# /content/val/Jessica Alba/Jessica Alba_40.jpg
# /content/val/Jessica Alba/Jessica Alba_41.jpg
# /content/val/Jessica Alba/Jessica Alba_42.jpg
# /content/val/Jessica Alba/Jessica Alba_48.jpg
# /content/val/Jessica Alba/Jessica Alba_49.jpg
# /content/val/Jessica Alba/Jessica Alba_54.jpg
# /content/val/Jessica Alba/Jessica Alba_61.jpg
# /content/val/Jessica Alba/Jessica Alba_64.jpg
# /content/val/Jessica Alba/Jessica Alba_66.jpg
# /content/val/Jessica Alba/Jessica Alba_72.jpg
# /content/val/Jessica Alba/Jessica Alba_75.jpg
# /content/val/Jessica Alba/Jessica Alba_85.jpg
# /content/val/Jessica Alba/Jessica Alba_94.jpg
# /content/val/Jessica Alba/Jessica Alba_96.jpg
# /content/val/Kashyap/Kashyap_15.jpg
# /content/val/Kashyap/Kashyap_17.jpg
# /content/val/Kashyap/Kashyap_2.jpg
# /content/val/Kashyap/Kashyap_25.jpg
# /content/val/Kashyap/Kashyap_29.jpg
# /content/val/Kashyap/Kashyap_4.jpg
# /content/val/Lisa Kudrow/Lisa Kudrow_1.jpg
# /content/val/Lisa Kudrow/Lisa Kudrow_14.jpg
# /content/val/Lisa Kudrow/Lisa Kudrow_15.jpg
# /content/val/Lisa Kudrow/Lisa Kudrow_3.jpg
# /content/val/Lisa Kudrow/Lisa Kudrow_4.jpg
# /content/val/Lisa Kudrow/Lisa Kudrow_40.jpg
# /content/val/Lisa Kudrow/Lisa Kudrow_43.jpg
# /content/val/Lisa Kudrow/Lisa Kudrow_44.jpg
# /content/val/Lisa Kudrow/Lisa Kudrow_47.jpg
# /content/val/Lisa Kudrow/Lisa Kudrow_50.jpg
# /content/val/Lisa Kudrow/Lisa Kudrow_57.jpg
# /content/val/Lisa Kudrow/Lisa Kudrow_58.jpg
# /content/val/Lisa Kudrow/Lisa Kudrow_59.jpg
# /content/val/Lisa Kudrow/Lisa Kudrow_67.jpg
# /content/val/Margot Robbie/Margot Robbie_1.jpg
# /content/val/Margot Robbie/Margot Robbie_14.jpg
# /content/val/Margot Robbie/Margot Robbie_23.jpg
# /content/val/Margot Robbie/Margot Robbie_24.jpg
# Multiple faces detected for /content/val/Margot Robbie/Margot Robbie_24.jpg, taking one with highest probability
# /content/val/Margot Robbie/Margot Robbie_25.jpg
# /content/val/Margot Robbie/Margot Robbie_29.jpg
# /content/val/Margot Robbie/Margot Robbie_32.jpg
# /content/val/Margot Robbie/Margot Robbie_4.jpg
# /content/val/Margot Robbie/Margot Robbie_47.jpg
# /content/val/Margot Robbie/Margot Robbie_48.jpg
# /content/val/Margot Robbie/Margot Robbie_54.jpg
# /content/val/Margot Robbie/Margot Robbie_59.jpg
# /content/val/Margot Robbie/Margot Robbie_61.jpg
# /content/val/Margot Robbie/Margot Robbie_64.jpg
# Multiple faces detected for /content/val/Margot Robbie/Margot Robbie_64.jpg, taking one with highest probability
# /content/val/Margot Robbie/Margot Robbie_65.jpg
# /content/val/Marmik/Marmik_1.jpg
# /content/val/Marmik/Marmik_16.jpg
# /content/val/Marmik/Marmik_17.jpg
# /content/val/Marmik/Marmik_18.jpg
# /content/val/Marmik/Marmik_5.jpg
# /content/val/Marmik/Marmik_6.jpg
# /content/val/Marmik/Marmik_9.jpg
# /content/val/Natalie Portman/Natalie Portman_102.jpg
# /content/val/Natalie Portman/Natalie Portman_103.jpg
# /content/val/Natalie Portman/Natalie Portman_19.jpg
# /content/val/Natalie Portman/Natalie Portman_21.jpg
# /content/val/Natalie Portman/Natalie Portman_24.jpg
# /content/val/Natalie Portman/Natalie Portman_25.jpg
# /content/val/Natalie Portman/Natalie Portman_27.jpg
# /content/val/Natalie Portman/Natalie Portman_40.jpg
# /content/val/Natalie Portman/Natalie Portman_44.jpg
# /content/val/Natalie Portman/Natalie Portman_45.jpg
# /content/val/Natalie Portman/Natalie Portman_54.jpg
# /content/val/Natalie Portman/Natalie Portman_58.jpg
# /content/val/Natalie Portman/Natalie Portman_59.jpg
# /content/val/Natalie Portman/Natalie Portman_60.jpg
# /content/val/Natalie Portman/Natalie Portman_61.jpg
# /content/val/Natalie Portman/Natalie Portman_62.jpg
# /content/val/Natalie Portman/Natalie Portman_64.jpg
# Multiple faces detected for /content/val/Natalie Portman/Natalie Portman_64.jpg, taking one with highest probability
# /content/val/Natalie Portman/Natalie Portman_72.jpg
# /content/val/Natalie Portman/Natalie Portman_74.jpg
# /content/val/Natalie Portman/Natalie Portman_78.jpg
# /content/val/Natalie Portman/Natalie Portman_84.jpg
# /content/val/Priyanka Chopra/Priyanka Chopra_11.jpg
# Multiple faces detected for /content/val/Priyanka Chopra/Priyanka Chopra_11.jpg, taking one with highest probability
# /content/val/Priyanka Chopra/Priyanka Chopra_17.jpg
# /content/val/Priyanka Chopra/Priyanka Chopra_18.jpg
# /content/val/Priyanka Chopra/Priyanka Chopra_2.jpg
# /content/val/Priyanka Chopra/Priyanka Chopra_22.jpg
# /content/val/Priyanka Chopra/Priyanka Chopra_26.jpg
# /content/val/Priyanka Chopra/Priyanka Chopra_30.jpg
# /content/val/Priyanka Chopra/Priyanka Chopra_31.jpg
# /content/val/Priyanka Chopra/Priyanka Chopra_35.jpg
# /content/val/Priyanka Chopra/Priyanka Chopra_40.jpg
# /content/val/Priyanka Chopra/Priyanka Chopra_51.jpg
# /content/val/Priyanka Chopra/Priyanka Chopra_6.jpg
# /content/val/Priyanka Chopra/Priyanka Chopra_60.jpg
# /content/val/Priyanka Chopra/Priyanka Chopra_7.jpg
# /content/val/Priyanka Chopra/Priyanka Chopra_70.jpg
# /content/val/Priyanka Chopra/Priyanka Chopra_71.jpg
# /content/val/Priyanka Chopra/Priyanka Chopra_83.jpg
# /content/val/Priyanka Chopra/Priyanka Chopra_87.jpg
# /content/val/Priyanka Chopra/Priyanka Chopra_9.jpg
# /content/val/Priyanka Chopra/Priyanka Chopra_92.jpg
# /content/val/Priyanka Chopra/Priyanka Chopra_98.jpg
# /content/val/Robert Downey Jr/Robert Downey Jr_10.jpg
# /content/val/Robert Downey Jr/Robert Downey Jr_106.jpg
# /content/val/Robert Downey Jr/Robert Downey Jr_18.jpg
# /content/val/Robert Downey Jr/Robert Downey Jr_23.jpg
# /content/val/Robert Downey Jr/Robert Downey Jr_27.jpg
# /content/val/Robert Downey Jr/Robert Downey Jr_28.jpg
# /content/val/Robert Downey Jr/Robert Downey Jr_30.jpg
# /content/val/Robert Downey Jr/Robert Downey Jr_36.jpg
# /content/val/Robert Downey Jr/Robert Downey Jr_38.jpg
# /content/val/Robert Downey Jr/Robert Downey Jr_40.jpg
# /content/val/Robert Downey Jr/Robert Downey Jr_5.jpg
# /content/val/Robert Downey Jr/Robert Downey Jr_51.jpg
# /content/val/Robert Downey Jr/Robert Downey Jr_56.jpg
# /content/val/Robert Downey Jr/Robert Downey Jr_64.jpg
# /content/val/Robert Downey Jr/Robert Downey Jr_65.jpg
# /content/val/Robert Downey Jr/Robert Downey Jr_66.jpg
# /content/val/Robert Downey Jr/Robert Downey Jr_69.jpg
# /content/val/Robert Downey Jr/Robert Downey Jr_70.jpg
# /content/val/Robert Downey Jr/Robert Downey Jr_72.jpg
# /content/val/Robert Downey Jr/Robert Downey Jr_82.jpg
# /content/val/Robert Downey Jr/Robert Downey Jr_9.jpg
# /content/val/Robert Downey Jr/Robert Downey Jr_91.jpg
# /content/val/Robert Downey Jr/Robert Downey Jr_92.jpg
# /content/val/Roger Federer/Roger Federer_1.jpg
# /content/val/Roger Federer/Roger Federer_10.jpg
# /content/val/Roger Federer/Roger Federer_16.jpg
# Multiple faces detected for /content/val/Roger Federer/Roger Federer_16.jpg, taking one with highest probability
# /content/val/Roger Federer/Roger Federer_28.jpg
# Multiple faces detected for /content/val/Roger Federer/Roger Federer_28.jpg, taking one with highest probability
# /content/val/Roger Federer/Roger Federer_30.jpg
# /content/val/Roger Federer/Roger Federer_32.jpg
# /content/val/Roger Federer/Roger Federer_34.jpg
# /content/val/Roger Federer/Roger Federer_41.jpg
# /content/val/Roger Federer/Roger Federer_45.jpg
# /content/val/Roger Federer/Roger Federer_66.jpg
# Multiple faces detected for /content/val/Roger Federer/Roger Federer_66.jpg, taking one with highest probability
# /content/val/Roger Federer/Roger Federer_67.jpg
# /content/val/Roger Federer/Roger Federer_7.jpg
# /content/val/Roger Federer/Roger Federer_71.jpg
# Multiple faces detected for /content/val/Roger Federer/Roger Federer_71.jpg, taking one with highest probability
# /content/val/Roger Federer/Roger Federer_74.jpg
# /content/val/Roger Federer/Roger Federer_8.jpg
# /content/val/Roger Federer/Roger Federer_9.jpg
# /content/val/Tom Cruise/Tom Cruise_0.jpg
# /content/val/Tom Cruise/Tom Cruise_17.jpg
# /content/val/Tom Cruise/Tom Cruise_20.jpg
# /content/val/Tom Cruise/Tom Cruise_21.jpg
# /content/val/Tom Cruise/Tom Cruise_27.jpg
# /content/val/Tom Cruise/Tom Cruise_29.jpg
# /content/val/Tom Cruise/Tom Cruise_31.jpg
# /content/val/Tom Cruise/Tom Cruise_32.jpg
# /content/val/Tom Cruise/Tom Cruise_44.jpg
# /content/val/Tom Cruise/Tom Cruise_45.jpg
# /content/val/Tom Cruise/Tom Cruise_51.jpg
# /content/val/Tom Cruise/Tom Cruise_6.jpg
# /content/val/Vijay Deverakonda/Vijay Deverakonda_1.jpg
# /content/val/Vijay Deverakonda/Vijay Deverakonda_14.jpg
# /content/val/Vijay Deverakonda/Vijay Deverakonda_22.jpg
# /content/val/Vijay Deverakonda/Vijay Deverakonda_30.jpg
# /content/val/Vijay Deverakonda/Vijay Deverakonda_31.jpg
# /content/val/Vijay Deverakonda/Vijay Deverakonda_32.jpg
# /content/val/Vijay Deverakonda/Vijay Deverakonda_33.jpg
# /content/val/Vijay Deverakonda/Vijay Deverakonda_43.jpg
# /content/val/Vijay Deverakonda/Vijay Deverakonda_45.jpg
# /content/val/Vijay Deverakonda/Vijay Deverakonda_46.jpg
# /content/val/Vijay Deverakonda/Vijay Deverakonda_47.jpg
# /content/val/Vijay Deverakonda/Vijay Deverakonda_5.jpg
# /content/val/Vijay Deverakonda/Vijay Deverakonda_52.jpg
# /content/val/Vijay Deverakonda/Vijay Deverakonda_53.jpg
# Multiple faces detected for /content/val/Vijay Deverakonda/Vijay Deverakonda_53.jpg, taking one with highest probability
# /content/val/Vijay Deverakonda/Vijay Deverakonda_6.jpg
# /content/val/Vijay Deverakonda/Vijay Deverakonda_69.jpg
# /content/val/Vijay Deverakonda/Vijay Deverakonda_71.jpg
# /content/val/Vijay Deverakonda/Vijay Deverakonda_76.jpg
# /content/val/Vijay Deverakonda/Vijay Deverakonda_77.jpg
# /content/val/Vijay Deverakonda/Vijay Deverakonda_81.jpg
# /content/val/Vijay Deverakonda/Vijay Deverakonda_84.jpg
# /content/val/Vijay Deverakonda/Vijay Deverakonda_89.jpg
# /content/val/Vijay Deverakonda/Vijay Deverakonda_92.jpg
# /content/val/Virat Kohli/Virat Kohli_10.jpg
# /content/val/Virat Kohli/Virat Kohli_12.jpg
# /content/val/Virat Kohli/Virat Kohli_21.jpg
# /content/val/Virat Kohli/Virat Kohli_25.jpg
# /content/val/Virat Kohli/Virat Kohli_26.jpg
# /content/val/Virat Kohli/Virat Kohli_28.jpg
# /content/val/Virat Kohli/Virat Kohli_36.jpg
# /content/val/Virat Kohli/Virat Kohli_38.jpg
# /content/val/Virat Kohli/Virat Kohli_42.jpg
# /content/val/Virat Kohli/Virat Kohli_43.jpg
# /content/val/Zac Efron/Zac Efron_10.jpg
# /content/val/Zac Efron/Zac Efron_13.jpg
# /content/val/Zac Efron/Zac Efron_22.jpg
# /content/val/Zac Efron/Zac Efron_25.jpg
# /content/val/Zac Efron/Zac Efron_27.jpg
# /content/val/Zac Efron/Zac Efron_3.jpg
# Multiple faces detected for /content/val/Zac Efron/Zac Efron_3.jpg, taking one with highest probability
# /content/val/Zac Efron/Zac Efron_32.jpg
# /content/val/Zac Efron/Zac Efron_36.jpg
# /content/val/Zac Efron/Zac Efron_40.jpg
# /content/val/Zac Efron/Zac Efron_41.jpg
# /content/val/Zac Efron/Zac Efron_47.jpg
# /content/val/Zac Efron/Zac Efron_54.jpg
# /content/val/Zac Efron/Zac Efron_55.jpg
# Multiple faces detected for /content/val/Zac Efron/Zac Efron_55.jpg, taking one with highest probability
# /content/val/Zac Efron/Zac Efron_60.jpg
# /content/val/Zac Efron/Zac Efron_67.jpg
# /content/val/Zac Efron/Zac Efron_80.jpg
# /content/val/Zac Efron/Zac Efron_85.jpg
# /content/val/Zac Efron/Zac Efron_86.jpg
# /content/val/Zac Efron/Zac Efron_9.jpg

# %% [markdown]
# ## Training
# The code trains a classification model using the training embeddings and labels:

# %%
print(class_to_idx)
import json

# File path for the text file
txt_file_path = "/content/drive/MyDrive/class.txt"

# Writing the variable content to the text file
with open(txt_file_path, "w") as file:
    json.dump(class_to_idx, file)

txt_file_path
# Out:
# {'Akshay Kumar': 0, 'Alexandra Daddario': 1, 'Alia Bhatt': 2, 'Amitabh Bachchan': 3, 'Andy Samberg': 4, 'Anushka Sharma': 5, 'Billie Eilish': 6, 'Brad Pitt': 7, 'Camila Cabello': 8, 'Charlize Theron': 9, 'Claire Holt': 10, 'Courtney Cox': 11, 'Dwayne Johnson': 12, 'Elizabeth Olsen': 13, 'Ellen Degeneres': 14, 'Henry Cavill': 15, 'Hrithik Roshan': 16, 'Hugh Jackman': 17, 'Jessica Alba': 18, 'Kashyap': 19, 'Lisa Kudrow': 20, 'Margot Robbie': 21, 'Marmik': 22, 'Natalie Portman': 23, 'Priyanka Chopra': 24, 'Robert Downey Jr': 25, 'Roger Federer': 26, 'Tom Cruise': 27, 'Vijay Deverakonda': 28, 'Virat Kohli': 29, 'Zac Efron': 30}
# '/content/drive/MyDrive/class.txt'

# %%
clf = train(embeddings, labels)

# Save the trained model
# %cd /content/drive/MyDrive
joblib.dump(clf, 'face_recognition_model.pkl')
# Out:
# /content/drive/MyDrive
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-62-57ebd6dbfa39> in <cell line: 6>()
#       4 get_ipython().run_line_magic('cd', '/content/drive/MyDrive')
#       5 joblib.dump(clf, 'face_recognition_model.pkl')
# ----> 6 cp -r /content/face_recognition_model.pkl /content/drive/MyDrive/face_recognition_model.pkl
#
# NameError: name 'cp' is not defined

# %%
# %cp -r /content/face_recognition_model.pkl /content/drive/MyDrive/face_recognition_model.pkl

# %% [markdown]
# ## Model Evaluation
# The code evaluates the trained model by printing a classification report and calculating the accuracy on the validation set:

# %%
idx_to_class = {v: k for k, v in class_to_idx.items()}
print(idx_to_class)

target_names = list(map(lambda i: i[1], sorted(idx_to_class.items(), key=lambda i: i[0])))
print(metrics.classification_report(labels, clf.predict(embeddings), target_names=target_names))

# Predict labels for validation set and calculate accuracy
y_val_pred = clf.predict(X_test)
accuracy = accuracy_score(y_test, y_val_pred)
print('Validation Accuracy: {:.2f}%'.format(accuracy*100))
# Out:
# {0: 'Akshay Kumar', 1: 'Alexandra Daddario', 2: 'Alia Bhatt', 3: 'Amitabh Bachchan', 4: 'Andy Samberg', 5: 'Anushka Sharma', 6: 'Billie Eilish', 7: 'Brad Pitt', 8: 'Camila Cabello', 9: 'Charlize Theron', 10: 'Claire Holt', 11: 'Courtney Cox', 12: 'Dwayne Johnson', 13: 'Elizabeth Olsen', 14: 'Ellen Degeneres', 15: 'Henry Cavill', 16: 'Hrithik Roshan', 17: 'Hugh Jackman', 18: 'Jessica Alba', 19: 'Kashyap', 20: 'Lisa Kudrow', 21: 'Margot Robbie', 22: 'Marmik', 23: 'Natalie Portman', 24: 'Priyanka Chopra', 25: 'Robert Downey Jr', 26: 'Roger Federer', 27: 'Tom Cruise', 28: 'Vijay Deverakonda', 29: 'Virat Kohli', 30: 'Zac Efron'}
#                     precision    recall  f1-score   support
#
#       Akshay Kumar       1.00      1.00      1.00        40
# Alexandra Daddario       1.00      1.00      1.00        73
#         Alia Bhatt       1.00      1.00      1.00        63
#   Amitabh Bachchan       1.00      1.00      1.00        59
#       Andy Samberg       1.00      1.00      1.00        73
#     Anushka Sharma       1.00      1.00      1.00        54
#      Billie Eilish       1.00      1.00      1.00        78
#          Brad Pitt       1.00      1.00      1.00        96
#     Camila Cabello       1.00      1.00      1.00        69
#    Charlize Theron       1.00      1.00      1.00        62
#        Claire Holt       1.00      1.00      1.00        76
#       Courtney Cox       1.00      1.00      1.00        64
#     Dwayne Johnson       1.00      1.00      1.00        48
#    Elizabeth Olsen       1.00      1.00      1.00        56
#    Ellen Degeneres       1.00      1.00      1.00        60
#       Henry Cavill       1.00      1.00      1.00        84
#     Hrithik Roshan       1.00      1.00      1.00        80
#       Hugh Jackman       1.00      1.00      1.00        89
#       Jessica Alba       1.00      1.00      1.00        86
#            Kashyap       1.00      1.00      1.00        24
#        Lisa Kudrow       1.00      1.00      1.00        56
#      Margot Robbie       1.00      1.00      1.00        57
#             Marmik       1.00      1.00      1.00        25
#    Natalie Portman       1.00      1.00      1.00        84
#    Priyanka Chopra       1.00      1.00      1.00        81
#   Robert Downey Jr       1.00      1.00      1.00        90
#      Roger Federer       1.00      1.00      1.00        61
#         Tom Cruise       1.00      1.00      1.00        46
#  Vijay Deverakonda       1.00      1.00      1.00        92
#        Virat Kohli       1.00      1.00      1.00        39
#          Zac Efron       1.00      1.00      1.00        72
#
#           accuracy                           1.00      2037
#          macro avg       1.00      1.00      1.00      2037
#       weighted avg       1.00      1.00      1.00      2037
#
# Validation Accuracy: 99.81%

# %% [markdown]
# ## Visualization
# The code visualizes the embeddings in a 2D space using PCA and plots a scatter plot with colored points representing different classes:

# %%
import os
import random
import matplotlib.pyplot as plt

def generate_random_color():
    """Hàm tạo màu ngẫu nhiên dưới dạng ký tự của matplotlib"""
    return "#{:06x}".format(random.randint(0, 0xFFFFFF))

def assign_colors(data_folder):
    """
    Gán màu ngẫu nhiên cho từng class trong thư mục dữ liệu.
    Trả về dictionary với class làm key và màu sắc làm giá trị.
    """
    # Lấy danh sách tất cả các class từ thư mục
    class_labels = [d for d in os.listdir(data_path) if os.path.isdir(os.path.join(data_path, d))]

    # Tạo dictionary gán màu ngẫu nhiên cho mỗi class
    colors = {}
    for label in class_labels:
        colors[label] = generate_random_color()

    return colors

# Sử dụng hàm với thư mục data của bạn
data_folder = "data"
color_mapping = assign_colors(data_folder)

# In ra kết quả
for label, color in color_mapping.items():
    print(f"'{label}' : '{color}',")
# Out:
# 'Claire Holt' : '#2b3256',
# 'Zac Efron' : '#ce3990',
# 'Marmik' : '#414e46',
# 'Akshay Kumar' : '#82b3fe',
# 'Virat Kohli' : '#995437',
# 'Alexandra Daddario' : '#1e9b03',
# 'Hrithik Roshan' : '#3ea890',
# 'Andy Samberg' : '#c76bb3',
# 'Billie Eilish' : '#a6f82e',
# 'Hugh Jackman' : '#d83e9f',
# 'Roger Federer' : '#8366d7',
# 'Elizabeth Olsen' : '#3b8ee5',
# 'Camila Cabello' : '#2bd4b0',
# 'Brad Pitt' : '#0c47cc',
# 'Margot Robbie' : '#1ebbda',
# 'Jessica Alba' : '#94a91d',
# 'Charlize Theron' : '#cfeaef',
# 'Dwayne Johnson' : '#50d843',
# 'Amitabh Bachchan' : '#57bbcf',
# 'Anushka Sharma' : '#5dc7af',
# 'Kashyap' : '#ab3ce3',
# 'Lisa Kudrow' : '#2af189',
# 'Alia Bhatt' : '#26c4e6',
# 'Ellen Degeneres' : '#49776f',
# 'Tom Cruise' : '#c1347d',
# 'Robert Downey Jr' : '#236f19',
# 'Courtney Cox' : '#7530c1',
# 'Vijay Deverakonda' : '#53523d',
# 'Priyanka Chopra' : '#02a86b',
# 'Henry Cavill' : '#9c43c1',
# 'Natalie Portman' : '#7dc957',

# %%
# Use PCA to reduce the dimensionality of the embeddings
pca = PCA(n_components=5)
embeddings_2d = pca.fit_transform(X_train)

# Map numeric labels to actual names
mapped_labels = [idx_to_class[label] for label in y_train]

# Define a function to assign colors to labels
def assign_colors(label):
    colors = {'Jessica Alba' : '#432638',
'Margot Robbie' : '#29da41',
'Hrithik Roshan' : '#8d79b8',
'Courtney Cox' : '#4ca42e',
'Akshay Kumar' : '#6e2400',
'Dwayne Johnson' : '#55eece',
'Tom Cruise' : '#45ffd5',
'Alia Bhatt' : '#84ffcd',
'Amitabh Bachchan' : '#c60c6a',
'Hugh Jackman' : '#e260c8',
'Robert Downey Jr' : '#117b88',
'Anushka Sharma' : '#a46c89',
'Natalie Portman' : '#0ca0c4',
'Charlize Theron' : '#2204b9',
'Andy Samberg' : '#cd39cb',
'Henry Cavill' : '#87fcd1',
'Marmik' : '#d29bf3',
'Camila Cabello' : '#3cec46',
'Ellen Degeneres' : '#6fdd06',
'Billie Eilish' : '#37aea2',
'Virat Kohli' : '#fa7876',
'Vijay Deverakonda' : '#e0f7e1',
'Alexandra Daddario' : '#241f59',
'Kashyap' : '#dd2ff9',
'Claire Holt' : '#e10c93',
'Zac Efron' : '#d2d6a0',
'Elizabeth Olsen' : '#cf3d06',
'Priyanka Chopra' : '#6a95ae',
'Brad Pitt' : '#e7bfa6',
'Lisa Kudrow' : '#548fc7',
'Roger Federer' : '#eea214'}
    return colors[label]

# Create color array for all points
colors = list(map(assign_colors, mapped_labels))

# Plot the 2D embeddings
plt.scatter(embeddings_2d[:, 0], embeddings_2d[:, 1], c=colors)
plt.show()

# %% [markdown]
# ## Face Recognition
#
# The code performs face recognition on randomly selected images from the validation set. It predicts the labels for the images and displays the predicted and actual labels along with the image:

# %%
transform_img = transforms.Compose([transforms.Resize(1024)])
transform = transforms.Compose([
        transforms.Resize(1024),
        transforms.ToTensor()
    ])



dataset_val = datasets.ImageFolder(root="/content/val")
val_samples = dataset_val.samples


random_samples = random.choices(val_samples, k=5)

for img_path, true_label in random_samples:

    img_ = transform_img(Image.open(img_path).convert('RGB'))
    img = transform(Image.open(img_path).convert('RGB'))

    # Extract features
    _, embedding = extract_features(mtcnn, facenet, img)
    if embedding is None:
        print("Could not find face on {}".format(img_path))
        continue
    if embedding.shape[0] > 1:
        print("Multiple faces detected for {}, taking one with highest probability".format(img_path))
        embedding = embedding[0, :]


    predicted_label = clf.predict(embedding.reshape(1, -1))
    print(clf.predict_proba(embedding))

    predicted_class = idx_to_class[predicted_label[0]]
    true_class = idx_to_class[true_label]

    plt.imshow(img_)
    plt.title(f'Predicted: {predicted_class}, Actual: {true_class}')
    plt.axis('off')
    plt.show()
# Out:
# [[0.00261571 0.00492686 0.00227588 0.00131004 0.00394009 0.00259945
#   0.01028582 0.00218526 0.00305849 0.02357028 0.00851833 0.0053948
#   0.00181934 0.0086984  0.0020612  0.00447037 0.00412072 0.00236613
#   0.00339255 0.00182048 0.00335136 0.86219425 0.00129403 0.01124262
#   0.00761289 0.00393494 0.00233749 0.00202547 0.0015915  0.00169774
#   0.00328751]]
# [[0.01150488 0.0062806  0.00710169 0.00561715 0.01656223 0.01053906
#   0.0152683  0.01035633 0.010951   0.00798505 0.01583364 0.00824478
#   0.70232078 0.00749862 0.00482667 0.01321708 0.02862828 0.0156406
#   0.00707612 0.01344825 0.00545936 0.00449761 0.0065475  0.00448739
#   0.00602073 0.02027103 0.00407156 0.00277878 0.01343123 0.00870273
#   0.00483096]]
# [[5.47741088e-03 2.06392440e-03 1.54229145e-03 1.42291885e-03
#   6.59105444e-03 2.94148149e-03 3.68120528e-03 9.07172792e-03
#   4.01738688e-03 1.56229911e-03 1.93634148e-03 1.81660739e-03
#   1.00719396e-03 1.81618690e-03 1.04883695e-03 5.04800181e-03
#   3.58882256e-03 2.85965254e-03 3.49966154e-03 1.60176213e-03
#   8.86867344e-04 1.88161064e-03 7.75402085e-04 2.61063161e-03
#   2.20437413e-03 9.20065412e-01 1.42557027e-03 1.17008164e-03
#   1.42091548e-03 1.33911186e-03 3.62525475e-03]]
# [[5.47741088e-03 2.06392440e-03 1.54229145e-03 1.42291885e-03
#   6.59105444e-03 2.94148149e-03 3.68120528e-03 9.07172792e-03
#   4.01738688e-03 1.56229911e-03 1.93634148e-03 1.81660739e-03
#   1.00719396e-03 1.81618690e-03 1.04883695e-03 5.04800181e-03
#   3.58882256e-03 2.85965254e-03 3.49966154e-03 1.60176213e-03
#   8.86867344e-04 1.88161064e-03 7.75402085e-04 2.61063161e-03
#   2.20437413e-03 9.20065412e-01 1.42557027e-03 1.17008164e-03
#   1.42091548e-03 1.33911186e-03 3.62525475e-03]]
# [[0.00497045 0.0029695  0.00514283 0.00259336 0.87280611 0.00719223
#   0.00269856 0.00693064 0.00601557 0.00168062 0.00353472 0.00402759
#   0.00212103 0.00257389 0.00245289 0.01141495 0.00690841 0.00596093
#   0.00387524 0.00359651 0.00234275 0.00248951 0.00313515 0.00443427
#   0.00298834 0.00966511 0.00385426 0.0049643  0.00188023 0.0016102
#   0.00316982]]

# %% [markdown]
# ## Intruder Recognition
#
# The code performs face recognition on a single image specified by img_path and displays the predicted label along with the image:

# %%
img_path = '/content/Robert_Downey_Jr._2014_Comic-Con.jpg'

img_ = transform_img(Image.open(img_path).convert('RGB'))
img = transform(Image.open(img_path).convert('RGB'))
_, embedding = extract_features(mtcnn, facenet, img)

predicted_label = clf.predict(embedding.reshape(1, -1))
# Convert label indexes back to original classes
predicted_class = idx_to_class[predicted_label[0]]
true_class = idx_to_class[true_label]
print((clf.predict_proba(embedding)))
thres = 0.6
if np.max(clf.predict_proba(embedding)) < thres:
    predicted_class = 'Intruder'


plt.imshow(img_)
plt.title(f'Predicted: {predicted_class}, Actual: {"TomCruise"}')
plt.axis('off')
plt.show()
# Out:
# [[0.01036201 0.0054595  0.00241913 0.00187912 0.00750045 0.0072702
#   0.00900522 0.00552411 0.00668203 0.00319237 0.00401724 0.00489578
#   0.0046938  0.00456318 0.00239901 0.01245266 0.01177603 0.01638978
#   0.00556922 0.00615736 0.00169421 0.00229276 0.00254705 0.00278672
#   0.00234176 0.83242419 0.00919802 0.00194153 0.00300645 0.00363585
#   0.00592327]]

# %%
from facenet_pytorch import MTCNN
import cv2
from PIL import Image
import os

# Khởi tạo MTCNN từ facenet_pytorch
mtcnn = MTCNN()

# Đường dẫn đến ảnh
image_path = "/content/OIP.jpg"

# Tải ảnh bằng OpenCV
image = cv2.imread(image_path)
if image is None:
    print("Không thể tải ảnh hoặc ảnh không tồn tại.")
else:
    # Chuyển ảnh sang định dạng RGB (yêu cầu của facenet_pytorch)
    image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

    # Chuyển ảnh từ OpenCV thành định dạng PIL
    image_pil = Image.fromarray(image_rgb)

    # Phát hiện khuôn mặt
    boxes, _ = mtcnn.detect(image_pil)

    # Tạo thư mục lưu ảnh khuôn mặt nếu chưa tồn tại
    output_dir = "/content/output"
    os.makedirs(output_dir, exist_ok=True)

    # Xử lý từng khuôn mặt được phát hiện
    for i, box in enumerate(boxes):
        x1, y1, x2, y2 = map(int, box)  # Chuyển tọa độ về số nguyên

        # Cắt khuôn mặt
        face_crop = image_rgb[y1:y2, x1:x2]

        # Lưu khuôn mặt đã cắt
        output_path = os.path.join(output_dir, f"face_{i+1}.jpg")
        cv2.imwrite(output_path, cv2.cvtColor(face_crop, cv2.COLOR_RGB2BGR))
        print(f"Khuôn mặt {i+1} đã được cắt và lưu tại {output_path}.")
# Out:
# Khuôn mặt 1 đã được cắt và lưu tại /content/output/face_1.jpg.

# %%
from google.colab import userdata
userdata.get('secretName')
